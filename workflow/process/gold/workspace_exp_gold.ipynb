# %%
import pandas as pd

# %%
df = pd.read_csv("/home/edcarlos/Data-Analytics-Comercio-Exterior/datalake/gold/exportacao_gold.csv", low_memory=False)
df.head()
# Out:
#   sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob data_exportacao  \
# 0       rj        107365.0           5           20      2023-03-01
# 1       sp             0.0           0           84      2023-12-01
# 2       rs             2.0           2          758      2023-04-01
# 3       rj             1.0           1          275      2023-05-01
# 4       mg             2.0           0            9      2023-10-01
#
#      cd_pais                                          cd_urf  \
# 0      china            aeroporto internacional de viracopos
# 1     suécia                                 porto de santos
# 2     angola  aeroporto internacional de sao paulo/guarulhos
# 3  argentina                                       são borja
# 4  argentina                                       são borja
#
#                                               cd_ncm          cd_unidade  \
# 0              outras partes de bombas para líquidos  quilograma liquido
# 1  arruelas de pressão e outras arruelas de segur...  quilograma liquido
# 2  outras partes de aparelhos para filtrar ou dep...  quilograma liquido
# 3  outras antenas e refletores de antenas, e suas...  quilograma liquido
# 4  rolamentos de roletes cilíndricos, de carga ra...    numero (unidade)
#
#        cd_via sg_ufmun data_exportacao_mun cd_sh4 cd_mun
# 0       aerea      NaN                 NaN    NaN    NaN
# 1    maritima      NaN                 NaN    NaN    NaN
# 2       aerea      NaN                 NaN    NaN    NaN
# 3  rodoviaria      NaN                 NaN    NaN    NaN
# 4  rodoviaria      NaN                 NaN    NaN    NaN

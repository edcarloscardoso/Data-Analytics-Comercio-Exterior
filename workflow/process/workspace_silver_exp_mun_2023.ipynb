# %%
import pandas as pd
# Caminho do arquivo
url_exp_mun_2023 = r'\\wsl$\Ubuntu\home\edcarlos\Data-Analytics-Comercio-Exterior\datalake\landing\exportacao_mun_2023.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_exp_mun_2023 = pd.read_csv(url_exp_mun_2023, sep=',')
# Exibir as primeiras linhas do DataFrame
df_exp_mun_2023.head()
# Out:
#    cd_sh4  cd_pais sg_ufmun   cd_mun  kg_liquido  vl_dolarfob  \
# 0    2209      127       ba  2919553          36           53
# 1    4009      493       sp  3456701         473        14008
# 2    8536      365       sp  3438709           2          181
# 3    8512       63       rj  3304201       15627       239105
# 4    1902      580       pr  4118204         287          368
#
#   data_exportacao_mun
# 0          2023-10-01
# 1          2023-11-01
# 2          2023-11-01
# 3          2023-08-01
# 4          2023-06-01

# %%
# Caminho do arquivo 
url_ncm_sh = r'\\wsl$\Ubuntu\home\edcarlos\Data-Analytics-Comercio-Exterior\datalake\raw_data\NCM_SH.csv' 
# Lendo o CSV para um DataFrame
df_ncm_sh = pd.read_csv(url_ncm_sh, sep=';', encoding='latin1')
# Exibir as primeiras linhas do DataFrame
df_ncm_sh.head()
# Out:
#    CO_SH6                                         NO_SH6_POR  \
# 0   10110  Animais vivos das espécies cavalar, asinina e ...
# 1   10111                 Cavalos reprodutores, de raça pura
# 2   10119                              Outros cavalos, vivos
# 3   10120                            Asininos e muares vivos
# 4   10121                  Cavalos reprodutores de raça pura
#
#                                      NO_SH6_ESP  \
# 0  Caballos y asnos, reproductores de raza pura
# 1           Caballos reproductores de raza pura
# 2                         Demás caballos, vivos
# 3              Asnos, mulos y burdéganos, vivos
# 4    Caballos de raza selecta para reproducción
#
#                             NO_SH6_ING  CO_SH4  \
# 0  Pure-bred breeding horses and asses     101
# 1            Pure-bred breeding horses     101
# 2                    Other live horses     101
# 3      Asses, mules and hinnies (live)     101
# 4            Pure-bred breeding horses     101
#
# ...

# %%
def carregar_e_mesclar_arquivos(url_exp_mun_2023: str, url_ncm_sh: str, 
                                chave_principal: str, chave_referencia: str, 
                                sep_principal: str = ',', sep_referencia: str = ';', 
                                encoding: str = 'latin1'):
    
    # Carregar os arquivos dentro da função
    df_exp_mun_2023 = pd.read_csv(url_exp_mun_2023, sep=sep_principal, encoding=encoding)
    df_ncm_sh = pd.read_csv(url_ncm_sh, sep=sep_referencia, encoding=encoding)

    # Garantir que as colunas de chave sejam strings
    df_exp_mun_2023[chave_principal] = df_exp_mun_2023[chave_principal].astype(str)
    df_ncm_sh[chave_referencia] = df_ncm_sh[chave_referencia].astype(str)

    # Realizar o merge
    df_resultado = df_exp_mun_2023.merge(df_ncm_sh, left_on=chave_principal, right_on=chave_referencia, how='left')

    return df_resultado

# Exemplo de uso
df_1 = carregar_e_mesclar_arquivos(
    url_exp_mun_2023=r'\\wsl$\Ubuntu\home\edcarlos\Data-Analytics-Comercio-Exterior\datalake\landing\exportacao_mun_2023.csv',
    url_ncm_sh=r'\\wsl$\Ubuntu\home\edcarlos\Data-Analytics-Comercio-Exterior\datalake\raw_data\NCM_SH.csv',
    chave_principal='cd_sh4',
    chave_referencia='CO_SH4'
)

# Exibir as primeiras linhas para verificar
df_1.head()
# Out:
#   cd_sh4  cd_pais sg_ufmun   cd_mun  kg_liquido  vl_dolarfob  \
# 0   2209      127       ba  2919553          36           53
# 1   4009      493       sp  3456701         473        14008
# 2   4009      493       sp  3456701         473        14008
# 3   4009      493       sp  3456701         473        14008
# 4   4009      493       sp  3456701         473        14008
#
#   data_exportacao_mun  CO_SH6  \
# 0          2023-10-01  220900
# 1          2023-11-01  400910
# 2          2023-11-01  400911
# 3          2023-11-01  400912
# 4          2023-11-01  400920
#
#                                           NO_SH6_POR  \
# 0  Vinagres e sucedâneos obtidos a partir do ácid...
# 1  Tubo de borracha vulcanizada, não endurecido, ...
# 2  Tubos de borracha vulcanizada não endurecida, ...
# 3  Tubos de borracha vulcanizada não endurecida, ...
# 4                   Tubos de borracha sem acessórios
#
#                                           NO_SH6_ESP  ...  \
# ...

# %%
print(df_1.columns) #verificando as colunas
# Out:
# Index(['cd_sh4', 'cd_pais', 'sg_ufmun', 'cd_mun', 'kg_liquido', 'vl_dolarfob',
#        'data_exportacao_mun', 'CO_SH6', 'NO_SH6_POR', 'NO_SH6_ESP',
#        'NO_SH6_ING', 'CO_SH4', 'NO_SH4_POR', 'NO_SH4_ESP', 'NO_SH4_ING',
#        'CO_SH2', 'NO_SH2_POR', 'NO_SH2_ESP', 'NO_SH2_ING', 'CO_NCM_SECROM',
#        'NO_SEC_POR', 'NO_SEC_ESP', 'NO_SEC_ING'],
#       dtype='object')

# %%
#removendo colunas
df_1 = df_1.drop(columns=['cd_sh4', 'CO_SH6', 'NO_SH6_POR', 'NO_SH6_ESP',
       'NO_SH6_ING', 'CO_SH4', 'NO_SH4_ESP', 'NO_SH4_ING',
       'CO_SH2', 'NO_SH2_POR', 'NO_SH2_ESP', 'NO_SH2_ING', 'CO_NCM_SECROM',
       'NO_SEC_POR', 'NO_SEC_ESP', 'NO_SEC_ING'])
df_1.head()
# Out:
#    cd_pais sg_ufmun   cd_mun  kg_liquido  vl_dolarfob data_exportacao_mun  \
# 0      127       ba  2919553          36           53          2023-10-01
# 1      493       sp  3456701         473        14008          2023-11-01
# 2      493       sp  3456701         473        14008          2023-11-01
# 3      493       sp  3456701         473        14008          2023-11-01
# 4      493       sp  3456701         473        14008          2023-11-01
#
#                                           NO_SH4_POR
# 0  Vinagres e seus sucedâneos obtidos a partir do...
# 1  Tubos de borracha vulcanizada não endurecida, ...
# 2  Tubos de borracha vulcanizada não endurecida, ...
# 3  Tubos de borracha vulcanizada não endurecida, ...
# 4  Tubos de borracha vulcanizada não endurecida, ...

# %%
# Caminho do arquivo
url_pais = r'\\wsl$\Ubuntu\home\edcarlos\Data-Analytics-Comercio-Exterior\datalake\raw_data\PAIS.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_pais = pd.read_csv(url_pais, sep=';',  encoding='latin1')  # Ou tente 'ISO-8859-1'
# Exibir as primeiras linhas do DataFrame
df_pais.head()
# Out:
#    CO_PAIS  CO_PAIS_ISON3 CO_PAIS_ISOA3                 NO_PAIS  \
# 0        0            898           ZZZ            Não Definido
# 1       13              4           AFG             Afeganistão
# 2       15            248           ALA            Aland, Ilhas
# 3       17              8           ALB                 Albânia
# 4       20            724           ESP  Alboran-Perejil, Ilhas
#
#                 NO_PAIS_ING             NO_PAIS_ESP
# 0               Not defined             No definido
# 1               Afghanistan              Afganistan
# 2             Aland Islands            Alans, Islas
# 3                   Albania                 Albania
# 4  Alboran-Perejil, Islands  Alboran-Perejil, Islas

# %%
# Função para mesclar os DataFrames já carregados
def mesclar_dataframes(df_base: pd.DataFrame, df_referencia: pd.DataFrame, 
                       chave_base: str, chave_referencia: str) -> pd.DataFrame:
    """
    Realiza a junção (merge) entre a base principal e o DataFrame de referência.
    """
    # Garantir que as colunas usadas no merge sejam strings
    df_base[chave_base] = df_base[chave_base].astype(str)
    df_referencia[chave_referencia] = df_referencia[chave_referencia].astype(str)

    # Realizar o merge
    df_resultante = df_base.merge(df_referencia, left_on=chave_base, right_on=chave_referencia, how='left')
    
    return df_resultante

# Exemplo de aplicação da função

# Já carregados anteriormente
# df_1 (base principal) e df_urf (referência) já estão definidos

# Mesclar os DataFrames
df_2 = mesclar_dataframes(df_base=df_1, df_referencia=df_pais, chave_base='cd_pais', chave_referencia='CO_PAIS')

# Exibir as primeiras linhas do DataFrame resultante
df_2.head()
# Out:
#   cd_pais sg_ufmun   cd_mun  kg_liquido  vl_dolarfob data_exportacao_mun  \
# 0     127       ba  2919553          36           53          2023-10-01
# 1     493       sp  3456701         473        14008          2023-11-01
# 2     493       sp  3456701         473        14008          2023-11-01
# 3     493       sp  3456701         473        14008          2023-11-01
# 4     493       sp  3456701         473        14008          2023-11-01
#
#                                           NO_SH4_POR CO_PAIS  CO_PAIS_ISON3  \
# 0  Vinagres e seus sucedâneos obtidos a partir do...     127            132
# 1  Tubos de borracha vulcanizada não endurecida, ...     493            484
# 2  Tubos de borracha vulcanizada não endurecida, ...     493            484
# 3  Tubos de borracha vulcanizada não endurecida, ...     493            484
# 4  Tubos de borracha vulcanizada não endurecida, ...     493            484
#
#   CO_PAIS_ISOA3     NO_PAIS NO_PAIS_ING NO_PAIS_ESP
# ...

# %%
print(df_2.columns) #verificar as colunas
# Out:
# Index(['cd_pais', 'sg_ufmun', 'cd_mun', 'kg_liquido', 'vl_dolarfob',
#        'data_exportacao_mun', 'NO_SH4_POR', 'CO_PAIS', 'CO_PAIS_ISON3',
#        'CO_PAIS_ISOA3', 'NO_PAIS', 'NO_PAIS_ING', 'NO_PAIS_ESP'],
#       dtype='object')

# %%
# removendo colunas
df_2 = df_2.drop(['cd_pais', 'CO_PAIS', 'CO_PAIS_ISON3',
       'CO_PAIS_ISOA3', 'NO_PAIS_ING', 'NO_PAIS_ESP'], axis=1)
df_2.head()
# Out:
#   sg_ufmun   cd_mun  kg_liquido  vl_dolarfob data_exportacao_mun  \
# 0       ba  2919553          36           53          2023-10-01
# 1       sp  3456701         473        14008          2023-11-01
# 2       sp  3456701         473        14008          2023-11-01
# 3       sp  3456701         473        14008          2023-11-01
# 4       sp  3456701         473        14008          2023-11-01
#
#                                           NO_SH4_POR     NO_PAIS
# 0  Vinagres e seus sucedâneos obtidos a partir do...  Cabo Verde
# 1  Tubos de borracha vulcanizada não endurecida, ...      México
# 2  Tubos de borracha vulcanizada não endurecida, ...      México
# 3  Tubos de borracha vulcanizada não endurecida, ...      México
# 4  Tubos de borracha vulcanizada não endurecida, ...      México

# %%
# Caminho do arquivo
url_uf_mun = r'\\wsl$\Ubuntu\home\edcarlos\Data-Analytics-Comercio-Exterior\datalake\raw_data\UF_MUN.csv' 
# Lendo o CSV para um DataFrame
df_uf_mun = pd.read_csv(url_uf_mun, sep=';',  encoding='latin1')  # Ou 'ISO-8859-1'
# Exibir as primeiras linhas do DataFrame
df_uf_mun.head()
# Out:
#    CO_MUN_GEO                  NO_MUN              NO_MUN_MIN SG_UF
# 0     2502003  BELEM DO BREJO DO CRUZ  Belém do Brejo do Cruz    PB
# 1     2502052      BERNARDINO BATISTA      Bernardino Batista    PB
# 2     2502102             BOA VENTURA             Boa Ventura    PB
# 3     2502151               BOA VISTA               Boa Vista    PB
# 4     2502201               BOM JESUS               Bom Jesus    PB

# %%
# Função para mesclar os DataFrames já carregados
def mesclar_dataframes(df_base: pd.DataFrame, df_referencia: pd.DataFrame, 
                       chave_base: str, chave_referencia: str) -> pd.DataFrame:
    """
    Realiza a junção (merge) entre a base principal e o DataFrame de referência.
    """
    # Garantir que as colunas usadas no merge sejam strings
    df_base[chave_base] = df_base[chave_base].astype(str)
    df_referencia[chave_referencia] = df_referencia[chave_referencia].astype(str)

    # Realizar o merge
    df_resultante = df_base.merge(df_referencia, left_on=chave_base, right_on=chave_referencia, how='left')
    
    return df_resultante

# Exemplo de aplicação da função

# Já carregados anteriormente
# df_1 (base principal) e df_urf (referência) já estão definidos

# Mesclar os DataFrames
df_3 = mesclar_dataframes(df_base=df_2, df_referencia=df_uf_mun, chave_base='cd_mun', chave_referencia='CO_MUN_GEO')

# Exibir as primeiras linhas do DataFrame resultante
df_3.head()
# Out:
#   sg_ufmun   cd_mun  kg_liquido  vl_dolarfob data_exportacao_mun  \
# 0       ba  2919553          36           53          2023-10-01
# 1       sp  3456701         473        14008          2023-11-01
# 2       sp  3456701         473        14008          2023-11-01
# 3       sp  3456701         473        14008          2023-11-01
# 4       sp  3456701         473        14008          2023-11-01
#
#                                           NO_SH4_POR     NO_PAIS CO_MUN_GEO  \
# 0  Vinagres e seus sucedâneos obtidos a partir do...  Cabo Verde    2919553
# 1  Tubos de borracha vulcanizada não endurecida, ...      México    3456701
# 2  Tubos de borracha vulcanizada não endurecida, ...      México    3456701
# 3  Tubos de borracha vulcanizada não endurecida, ...      México    3456701
# 4  Tubos de borracha vulcanizada não endurecida, ...      México    3456701
#
#                    NO_MUN              NO_MUN_MIN SG_UF
# 0  LUIS EDUARDO MAGALHAES  Luís Eduardo Magalhães    BA
# ...

# %%
print(df_3.columns) #verificar colunas
# Out:
# Index(['sg_ufmun', 'cd_mun', 'kg_liquido', 'vl_dolarfob',
#        'data_exportacao_mun', 'NO_SH4_POR', 'NO_PAIS', 'CO_MUN_GEO', 'NO_MUN',
#        'NO_MUN_MIN', 'SG_UF'],
#       dtype='object')

# %%
df_3 = df_3.drop(['cd_mun', 'CO_MUN_GEO', 'NO_MUN', 'SG_UF'], axis=1) #remover colunas
df_3.head()
# Out:
#   sg_ufmun  kg_liquido  vl_dolarfob data_exportacao_mun  \
# 0       ba          36           53          2023-10-01
# 1       sp         473        14008          2023-11-01
# 2       sp         473        14008          2023-11-01
# 3       sp         473        14008          2023-11-01
# 4       sp         473        14008          2023-11-01
#
#                                           NO_SH4_POR     NO_PAIS  \
# 0  Vinagres e seus sucedâneos obtidos a partir do...  Cabo Verde
# 1  Tubos de borracha vulcanizada não endurecida, ...      México
# 2  Tubos de borracha vulcanizada não endurecida, ...      México
# 3  Tubos de borracha vulcanizada não endurecida, ...      México
# 4  Tubos de borracha vulcanizada não endurecida, ...      México
#
#                NO_MUN_MIN
# 0  Luís Eduardo Magalhães
# 1                 Vinhedo
# 2                 Vinhedo
# 3                 Vinhedo
# 4                 Vinhedo

# %%
#renomear colunas
df_3 = df_3.rename(columns={  
    'NO_SH4_POR': 'cd_sh4',
    'NO_PAIS': 'cd_pais',
    'NO_MUN_MIN': 'cd_mun'
    })
df_3.columns = df_3.columns.str.strip().str.lower().str.replace(' ', '_')
df_3.head()
# Out:
#   sg_ufmun  kg_liquido  vl_dolarfob data_exportacao_mun  \
# 0       ba          36           53          2023-10-01
# 1       sp         473        14008          2023-11-01
# 2       sp         473        14008          2023-11-01
# 3       sp         473        14008          2023-11-01
# 4       sp         473        14008          2023-11-01
#
#                                               cd_sh4     cd_pais  \
# 0  Vinagres e seus sucedâneos obtidos a partir do...  Cabo Verde
# 1  Tubos de borracha vulcanizada não endurecida, ...      México
# 2  Tubos de borracha vulcanizada não endurecida, ...      México
# 3  Tubos de borracha vulcanizada não endurecida, ...      México
# 4  Tubos de borracha vulcanizada não endurecida, ...      México
#
#                    cd_mun
# 0  Luís Eduardo Magalhães
# 1                 Vinhedo
# 2                 Vinhedo
# 3                 Vinhedo
# 4                 Vinhedo

# %%
def padronizar_colunas(df, colunas):
    """
    Remove espaços extras e converte os valores das colunas especificadas para minúsculas.

    Parâmetros:
        df (pd.DataFrame): DataFrame de entrada.
        colunas (list): Lista de colunas a serem padronizadas.

    Retorna:
        pd.DataFrame: DataFrame com as colunas padronizadas.
    """
    df[colunas] = df[colunas].apply(lambda x: x.str.strip().str.lower())
    return df

df_4 = padronizar_colunas(df_3, ['cd_sh4', 'cd_pais', 'cd_mun'])
df_4.head()
# Out:
#   sg_ufmun  kg_liquido  vl_dolarfob data_exportacao_mun  \
# 0       ba          36           53          2023-10-01
# 1       sp         473        14008          2023-11-01
# 2       sp         473        14008          2023-11-01
# 3       sp         473        14008          2023-11-01
# 4       sp         473        14008          2023-11-01
#
#                                               cd_sh4     cd_pais  \
# 0  vinagres e seus sucedâneos obtidos a partir do...  cabo verde
# 1  tubos de borracha vulcanizada não endurecida, ...      méxico
# 2  tubos de borracha vulcanizada não endurecida, ...      méxico
# 3  tubos de borracha vulcanizada não endurecida, ...      méxico
# 4  tubos de borracha vulcanizada não endurecida, ...      méxico
#
#                    cd_mun
# 0  luís eduardo magalhães
# 1                 vinhedo
# 2                 vinhedo
# 3                 vinhedo
# 4                 vinhedo

# %%
caminho = "/home/edcarlos/Data-Analytics-Comercio-Exterior/datalake/silver/exportacao_mun_2023_m.csv" #salvando as alterações em outro arquivo
df_4.to_csv(caminho, index=False)
print("Arquivo salvo com sucesso!")
# Out:
# Arquivo salvo com sucesso!

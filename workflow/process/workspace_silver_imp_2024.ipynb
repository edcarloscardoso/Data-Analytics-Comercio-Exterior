# %%
import pandas as pd
# Caminho do arquivo
importacao_2024 = r'\\wsl$\Ubuntu\home\edcarlos\work_environment\datalake\landing\importacao_2024.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df = pd.read_csv(importacao_2024, sep=',')
# Exibir as primeiras linhas do DataFrame
df.head()
# Out:
#      cd_ncm  cd_unidade  cd_pais sg_ufncm  cd_via  cd_urf  qt_estatistica  \
# 0  84818092          11      161       sc       1  927800             344
# 1  90304090          11      249       sp       4  817700               1
# 2  39172300          10       23       pe       4  417901            1128
# 3  85444200          10      160       mg       4  817700             824
# 4  84439942          10      190       sc       4  817600               3
#
#    kg_liquido  vl_dolarfob  vl_frete  vl_seguro data_importacao
# 0          90         6823        77         10      2024-10-01
# 1           9         4890       147          7      2024-04-01
# 2        1128        28129     20688          7      2024-01-01
# 3         824        66958     11276         45      2024-06-01
# 4           3         2060        37          0      2024-10-01

# %%
# Caminho do arquivo
arquivo_ncm = r'\\wsl$\Ubuntu\home\edcarlos\work_environment\datalake\raw_data\NCM.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_ncm = pd.read_csv(arquivo_ncm, sep=';', encoding='latin1')
# Exibir as primeiras linhas do DataFrame
df_ncm.head()
# Out:
#      CO_NCM  CO_UNID  CO_SH6  CO_PPE  CO_PPI  CO_FAT_AGREG CO_CUCI_ITEM  \
# 0  49011000       10  490110  3521.0  3521.0           3.0        89215
# 1  49019100       10  490191  3521.0  3521.0           3.0        89216
# 2  49019900       10  490199  3521.0  3521.0           3.0        89219
# 3  49021000       10  490210  3521.0  3521.0           3.0        89221
# 4  52102910       10  521029  3840.0  3840.0           3.0        65251
#
#    CO_CGCE_N3  CO_SIIT  CO_ISIC_CLASSE  CO_EXP_SUBSET  \
# 0         322   9000.0            5811         8099.0
# 1         322   9000.0            5811         8099.0
# 2         322   9000.0            5811         8099.0
# 3         322   9000.0            5813         8099.0
# 4         240   4000.0            1312         1605.0
#
#                                           NO_NCM_POR  \
# 0  Livros, brochuras e impressos semelhantes, em ...
# 1   Dicionários e enciclopédias, mesmo em fascículos
# 2   Outros livros, brochuras e impressos semelhantes
# 3  Jornais e publicações periódicas, impressos, m...
# 4  Tecidos de algodão que contenham menos de 85 %...
#
#                                           NO_NCM_ESP  \
# 0  Libros, folletos, impresos similares, en hojas...
# 1  Diccionarios y enciclopedias, incluso en fascí...
# 2        Otros libros, folletos y impresos similares
# 3  Diarios y publicaciones, impresos, periodo>=4 ...
# 4  Tejidos de algodón, blanqueados, con fibras si...
#
#                                           NO_NCM_ING
# 0  Books, brochures, similar printed papers, in s...
# 1  Dictionaries and encyclopaedias, serial instal...
# 2   Oth.printed books, brochures and similar printed
# 3  Newspapers, journals, printed, periodical>=4 t...
# 4  Fabrics of cotton, bleached, synthetic or arti...

# %%
# Carregar o arquivo principal que contém a coluna cd_ncm
df = pd.read_csv(importacao_2024, sep=',', encoding='latin1')

# Carregar o arquivo que contém a coluna CO_NCM
df_ncm = pd.read_csv(arquivo_ncm, sep=';', encoding='latin1')

# Garantir que cd_ncm seja string
df['cd_ncm'] = df['cd_ncm'].astype(str)

# Garantir que CO_NCM seja string
df_ncm['CO_NCM'] = df_ncm['CO_NCM'].astype(str)

# Fazer o merge para substituir os códigos pelos nomes dos países
df = df.merge(df_ncm, left_on='cd_ncm', right_on='CO_NCM', how='left')

# Exibir as primeiras linhas para verificar se deu certo
df.head()
# Out:
#      cd_ncm  cd_unidade  cd_pais sg_ufncm  cd_via  cd_urf  qt_estatistica  \
# 0  84818092          11      161       sc       1  927800             344
# 1  90304090          11      249       sp       4  817700               1
# 2  39172300          10       23       pe       4  417901            1128
# 3  85444200          10      160       mg       4  817700             824
# 4  84439942          10      190       sc       4  817600               3
#
#    kg_liquido  vl_dolarfob  vl_frete  ...  CO_PPI CO_FAT_AGREG CO_CUCI_ITEM  \
# 0          90         6823        77  ...  3857.0          3.0         7478
# 1           9         4890       147  ...  3715.0          3.0        87477
# 2        1128        28129     20688  ...  3717.0          3.0         5812
# 3         824        66958     11276  ...  3268.0          3.0        77316
# 4           3         2060        37  ...  3372.0          3.0        75197
#
#    CO_CGCE_N3  CO_SIIT  CO_ISIC_CLASSE  CO_EXP_SUBSET  \
# 0         270   2000.0            2813          914.0
# 1         110   1000.0            2651         2600.0
# 2         240   3000.0            2220         1407.0
# 3         240   2000.0            2732         1104.0
# 4         270   2000.0            2829         2600.0
#
#                                           NO_NCM_POR  \
# 0                                Válvulas solenóides
# 1  Outros instrumentos e aparelhos para telecomun...
# 2     Tubo rígido, de polímeros de cloreto de vinila
# 3  Outros condutores elétricos tensão <= 100 v, c...
# 4                        Outras cabeças de impressão
#
#                                           NO_NCM_ESP  \
# 0                                Válvulas solenoides
# 1  Los demás instrumentos y aparatos p/telecomuni...
# 2     Tubo rígido, de polímeros de cloruro de vinilo
# 3  Otros conductores eléctricos p/ tension <=100v...
# 4                       Otros cabezales de impresión
#
#                                           NO_NCM_ING
# 0                                    Solenoid valves
# 1  Other instruments and apparatus,for telecommun...
# 2         Rigid tubes, of polymers of vinyl chloride
# 3  Other electric conductors f/tension<=100v, wit...
# 4                                  Other print heads
#
# [5 rows x 26 columns]

# %%
print(df.columns) #verificar colunas
# Out:
# Index(['cd_ncm', 'cd_unidade', 'cd_pais', 'sg_ufncm', 'cd_via', 'cd_urf',
#        'qt_estatistica', 'kg_liquido', 'vl_dolarfob', 'vl_frete', 'vl_seguro',
#        'data_importacao', 'CO_NCM', 'CO_UNID', 'CO_SH6', 'CO_PPE', 'CO_PPI',
#        'CO_FAT_AGREG', 'CO_CUCI_ITEM', 'CO_CGCE_N3', 'CO_SIIT',
#        'CO_ISIC_CLASSE', 'CO_EXP_SUBSET', 'NO_NCM_POR', 'NO_NCM_ESP',
#        'NO_NCM_ING'],
#       dtype='object')

# %%
#remover colunas
df = df.drop(columns=['cd_ncm', 'CO_NCM', 'CO_UNID', 'CO_SH6', 'CO_PPE', 'CO_PPI', 'CO_FAT_AGREG', 'CO_CUCI_ITEM', 'CO_CGCE_N3', 'CO_SIIT', 'CO_ISIC_CLASSE', 'CO_EXP_SUBSET', 'NO_NCM_ESP', 'NO_NCM_ING'])
df.head()
# Out:
#    cd_unidade  cd_pais sg_ufncm  cd_via  cd_urf  qt_estatistica  kg_liquido  \
# 0          11      161       sc       1  927800             344          90
# 1          11      249       sp       4  817700               1           9
# 2          10       23       pe       4  417901            1128        1128
# 3          10      160       mg       4  817700             824         824
# 4          10      190       sc       4  817600               3           3
#
#    vl_dolarfob  vl_frete  vl_seguro data_importacao  \
# 0         6823        77         10      2024-10-01
# 1         4890       147          7      2024-04-01
# 2        28129     20688          7      2024-01-01
# 3        66958     11276         45      2024-06-01
# 4         2060        37          0      2024-10-01
#
#                                           NO_NCM_POR
# 0                                Válvulas solenóides
# 1  Outros instrumentos e aparelhos para telecomun...
# 2     Tubo rígido, de polímeros de cloreto de vinila
# 3  Outros condutores elétricos tensão <= 100 v, c...
# 4                        Outras cabeças de impressão

# %%
# Caminho do arquivo
arquivo_urf = r'\\wsl$\Ubuntu\home\edcarlos\work_environment\datalake\raw_data\URF.csv' 
# Lendo o CSV para um DataFrame
df_urf = pd.read_csv(arquivo_urf, sep=';',  encoding='latin1')  # Ou 'ISO-8859-1'
# Exibir as primeiras linhas do DataFrame
df_urf.head()
# Out:
#    CO_URF                                             NO_URF
# 0     910  0000910 - SEFAZ-SC - CONVENIO CONSULTA SISTEMA...
# 1  110100                                 0110100 - BRASILIA
# 2  117600      0117600 - AEROPORTO INTERNACIONAL DE BRASILIA
# 3  120100                                  0120100 - GOIANIA
# 4  120102                                  0120102 - CATALAO

# %%
df1 = df['cd_urf'] = df['cd_urf'].astype(str)
df_urf['CO_URF'] = df_urf['CO_URF'].astype(str)

# Fazer o merge para substituir os códigos pelos nomes das URFs
df1 = df.merge(df_urf, left_on='cd_urf', right_on='CO_URF', how='left')

# Exibir as primeiras linhas para verificar se deu certo
df1.head()
# Out:
#    cd_unidade  cd_pais sg_ufncm  cd_via  cd_urf  qt_estatistica  kg_liquido  \
# 0          11      161       sc       1  927800             344          90
# 1          11      249       sp       4  817700               1           9
# 2          10       23       pe       4  417901            1128        1128
# 3          10      160       mg       4  817700             824         824
# 4          10      190       sc       4  817600               3           3
#
#    vl_dolarfob  vl_frete  vl_seguro data_importacao  \
# 0         6823        77         10      2024-10-01
# 1         4890       147          7      2024-04-01
# 2        28129     20688          7      2024-01-01
# 3        66958     11276         45      2024-06-01
# 4         2060        37          0      2024-10-01
#
#                                           NO_NCM_POR  CO_URF  \
# 0                                Válvulas solenóides  927800
# 1  Outros instrumentos e aparelhos para telecomun...  817700
# 2     Tubo rígido, de polímeros de cloreto de vinila  417901
# 3  Outros condutores elétricos tensão <= 100 v, c...  817700
# 4                        Outras cabeças de impressão  817600
#
#                                               NO_URF
# 0                                   0927800 - ITAJAI
# 1     0817700 - AEROPORTO INTERNACIONAL DE VIRACOPOS
# 2  0417901 - IRF - AEROPORTO INTERNACIONAL DOS GU...
# 3     0817700 - AEROPORTO INTERNACIONAL DE VIRACOPOS
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...

# %%
df1 = df1.drop(['cd_urf', 'CO_URF'], axis=1)
df1.head()
# Out:
#    cd_unidade  cd_pais sg_ufncm  cd_via  qt_estatistica  kg_liquido  \
# 0          11      161       sc       1             344          90
# 1          11      249       sp       4               1           9
# 2          10       23       pe       4            1128        1128
# 3          10      160       mg       4             824         824
# 4          10      190       sc       4               3           3
#
#    vl_dolarfob  vl_frete  vl_seguro data_importacao  \
# 0         6823        77         10      2024-10-01
# 1         4890       147          7      2024-04-01
# 2        28129     20688          7      2024-01-01
# 3        66958     11276         45      2024-06-01
# 4         2060        37          0      2024-10-01
#
#                                           NO_NCM_POR  \
# 0                                Válvulas solenóides
# 1  Outros instrumentos e aparelhos para telecomun...
# 2     Tubo rígido, de polímeros de cloreto de vinila
# 3  Outros condutores elétricos tensão <= 100 v, c...
# 4                        Outras cabeças de impressão
#
#                                               NO_URF
# 0                                   0927800 - ITAJAI
# 1     0817700 - AEROPORTO INTERNACIONAL DE VIRACOPOS
# 2  0417901 - IRF - AEROPORTO INTERNACIONAL DOS GU...
# 3     0817700 - AEROPORTO INTERNACIONAL DE VIRACOPOS
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...

# %%
# Caminho do arquivo
arquivo_via = r'\\wsl$\Ubuntu\home\edcarlos\work_environment\datalake\raw_data\VIA.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_via = pd.read_csv(arquivo_via, sep=';',  encoding='latin1')  # Ou tente 'ISO-8859-1'
# Exibir as primeiras linhas do DataFrame
df_via.head()
# Out:
#    CO_VIA               NO_VIA
# 0      99     VIA DESCONHECIDA
# 1      13          POR REBOQUE
# 2      11              COURIER
# 3      15  VICINAL FRONTEIRICO
# 4      14                DUTOS

# %%
# Garantir que cd_urf e CO_URF sejam do mesmo tipo
df2 = df1['cd_via'] = df['cd_via'].astype(str)
df_via['CO_VIA'] = df_via['CO_VIA'].astype(str)

# Fazer o merge para substituir os códigos pelos nomes das URFs
df2 = df1.merge(df_via, left_on='cd_via', right_on='CO_VIA', how='left')

# Exibir as primeiras linhas para verificar se deu certo
df2.head()
# Out:
#    cd_unidade  cd_pais sg_ufncm cd_via  qt_estatistica  kg_liquido  \
# 0          11      161       sc      1             344          90
# 1          11      249       sp      4               1           9
# 2          10       23       pe      4            1128        1128
# 3          10      160       mg      4             824         824
# 4          10      190       sc      4               3           3
#
#    vl_dolarfob  vl_frete  vl_seguro data_importacao  \
# 0         6823        77         10      2024-10-01
# 1         4890       147          7      2024-04-01
# 2        28129     20688          7      2024-01-01
# 3        66958     11276         45      2024-06-01
# 4         2060        37          0      2024-10-01
#
#                                           NO_NCM_POR  \
# 0                                Válvulas solenóides
# 1  Outros instrumentos e aparelhos para telecomun...
# 2     Tubo rígido, de polímeros de cloreto de vinila
# 3  Outros condutores elétricos tensão <= 100 v, c...
# 4                        Outras cabeças de impressão
#
#                                               NO_URF CO_VIA    NO_VIA
# 0                                   0927800 - ITAJAI      1  MARITIMA
# 1     0817700 - AEROPORTO INTERNACIONAL DE VIRACOPOS      4     AEREA
# 2  0417901 - IRF - AEROPORTO INTERNACIONAL DOS GU...      4     AEREA
# 3     0817700 - AEROPORTO INTERNACIONAL DE VIRACOPOS      4     AEREA
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...      4     AEREA

# %%
df2 = df2.drop(['cd_via', 'CO_VIA'], axis=1)
df2.head()
# Out:
#    cd_unidade  cd_pais sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  \
# 0          11      161       sc             344          90         6823
# 1          11      249       sp               1           9         4890
# 2          10       23       pe            1128        1128        28129
# 3          10      160       mg             824         824        66958
# 4          10      190       sc               3           3         2060
#
#    vl_frete  vl_seguro data_importacao  \
# 0        77         10      2024-10-01
# 1       147          7      2024-04-01
# 2     20688          7      2024-01-01
# 3     11276         45      2024-06-01
# 4        37          0      2024-10-01
#
#                                           NO_NCM_POR  \
# 0                                Válvulas solenóides
# 1  Outros instrumentos e aparelhos para telecomun...
# 2     Tubo rígido, de polímeros de cloreto de vinila
# 3  Outros condutores elétricos tensão <= 100 v, c...
# 4                        Outras cabeças de impressão
#
#                                               NO_URF    NO_VIA
# 0                                   0927800 - ITAJAI  MARITIMA
# 1     0817700 - AEROPORTO INTERNACIONAL DE VIRACOPOS     AEREA
# 2  0417901 - IRF - AEROPORTO INTERNACIONAL DOS GU...     AEREA
# 3     0817700 - AEROPORTO INTERNACIONAL DE VIRACOPOS     AEREA
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA

# %%
# Caminho do arquivo
arquivo_pais = r'\\wsl$\Ubuntu\home\edcarlos\work_environment\datalake\raw_data\PAIS.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_pais = pd.read_csv(arquivo_pais, sep=';',  encoding='latin1')  # Ou tente 'ISO-8859-1'
# Exibir as primeiras linhas do DataFrame
df_pais.head()
# Out:
#    CO_PAIS  CO_PAIS_ISON3 CO_PAIS_ISOA3                 NO_PAIS  \
# 0        0            898           ZZZ            Não Definido
# 1       13              4           AFG             Afeganistão
# 2       15            248           ALA            Aland, Ilhas
# 3       17              8           ALB                 Albânia
# 4       20            724           ESP  Alboran-Perejil, Ilhas
#
#                 NO_PAIS_ING             NO_PAIS_ESP
# 0               Not defined             No definido
# 1               Afghanistan              Afganistan
# 2             Aland Islands            Alans, Islas
# 3                   Albania                 Albania
# 4  Alboran-Perejil, Islands  Alboran-Perejil, Islas

# %%
# Garantir que cd_urf e CO_URF sejam do mesmo tipo
df3 = df2['cd_pais'] = df['cd_pais'].astype(str)
df_pais['CO_PAIS'] = df_pais['CO_PAIS'].astype(str)

# Fazer o merge para substituir os códigos pelos nomes das URFs
df3 = df2.merge(df_pais, left_on='cd_pais', right_on='CO_PAIS', how='left')

# Exibir as primeiras linhas para verificar se deu certo
df3.head()
# Out:
#    cd_unidade cd_pais sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  \
# 0          11     161       sc             344          90         6823
# 1          11     249       sp               1           9         4890
# 2          10      23       pe            1128        1128        28129
# 3          10     160       mg             824         824        66958
# 4          10     190       sc               3           3         2060
#
#    vl_frete  vl_seguro data_importacao  \
# 0        77         10      2024-10-01
# 1       147          7      2024-04-01
# 2     20688          7      2024-01-01
# 3     11276         45      2024-06-01
# 4        37          0      2024-10-01
#
#                                           NO_NCM_POR  \
# 0                                Válvulas solenóides
# 1  Outros instrumentos e aparelhos para telecomun...
# 2     Tubo rígido, de polímeros de cloreto de vinila
# 3  Outros condutores elétricos tensão <= 100 v, c...
# 4                        Outras cabeças de impressão
#
#                                               NO_URF    NO_VIA CO_PAIS  \
# 0                                   0927800 - ITAJAI  MARITIMA     161
# 1     0817700 - AEROPORTO INTERNACIONAL DE VIRACOPOS     AEREA     249
# 2  0417901 - IRF - AEROPORTO INTERNACIONAL DOS GU...     AEREA      23
# 3     0817700 - AEROPORTO INTERNACIONAL DE VIRACOPOS     AEREA     160
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA     190
#
#    CO_PAIS_ISON3 CO_PAIS_ISOA3           NO_PAIS    NO_PAIS_ING  \
# 0            158           TWN  Taiwan (Formosa)         Taiwan
# 1            840           USA    Estados Unidos  United States
# 2            276           DEU          Alemanha        Germany
# 3            156           CHN             China          China
# 4            410           KOR     Coreia do Sul    South Korea
#
#       NO_PAIS_ESP
# 0          Taiwán
# 1  Estados Unidos
# 2        Alemania
# 3           China
# 4     Corea (Sur)

# %%
print(df3.columns) #verificando colunas
# Out:
# Index(['cd_unidade', 'cd_pais', 'sg_ufncm', 'qt_estatistica', 'kg_liquido',
#        'vl_dolarfob', 'vl_frete', 'vl_seguro', 'data_importacao', 'NO_NCM_POR',
#        'NO_URF', 'NO_VIA', 'CO_PAIS', 'CO_PAIS_ISON3', 'CO_PAIS_ISOA3',
#        'NO_PAIS', 'NO_PAIS_ING', 'NO_PAIS_ESP'],
#       dtype='object')

# %%
#removendo colunas
df3 = df3.drop(columns=['cd_pais', 'CO_PAIS', 'CO_PAIS_ISON3',
       'CO_PAIS_ISOA3', 'NO_PAIS_ING', 'NO_PAIS_ESP'])
df3.head()
# Out:
#    cd_unidade sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  vl_frete  \
# 0          11       sc             344          90         6823        77
# 1          11       sp               1           9         4890       147
# 2          10       pe            1128        1128        28129     20688
# 3          10       mg             824         824        66958     11276
# 4          10       sc               3           3         2060        37
#
#    vl_seguro data_importacao  \
# 0         10      2024-10-01
# 1          7      2024-04-01
# 2          7      2024-01-01
# 3         45      2024-06-01
# 4          0      2024-10-01
#
#                                           NO_NCM_POR  \
# 0                                Válvulas solenóides
# 1  Outros instrumentos e aparelhos para telecomun...
# 2     Tubo rígido, de polímeros de cloreto de vinila
# 3  Outros condutores elétricos tensão <= 100 v, c...
# 4                        Outras cabeças de impressão
#
#                                               NO_URF    NO_VIA  \
# 0                                   0927800 - ITAJAI  MARITIMA
# 1     0817700 - AEROPORTO INTERNACIONAL DE VIRACOPOS     AEREA
# 2  0417901 - IRF - AEROPORTO INTERNACIONAL DOS GU...     AEREA
# 3     0817700 - AEROPORTO INTERNACIONAL DE VIRACOPOS     AEREA
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA
#
#             NO_PAIS
# 0  Taiwan (Formosa)
# 1    Estados Unidos
# 2          Alemanha
# 3             China
# 4     Coreia do Sul

# %%
#renomeando colunas
df4 = df3.rename(columns={  
    'cd_unidade': 'cd_unidade',
    'sg_ufncm': 'sg_ufncm',
    'qt_estatistica': 'qt_estatistica',
    'kg_liquido': 'kg_liquido',
    'vl_dolarfob': 	'vl_dolarfob',
    'vl_frete': 'vl_frete',
    'vl_seguro': 'vl_seguro',
    'data_importacao_2023': 'data_importacao_2023',
    'NO_NCM_POR': 'cd_ncm',
    'NO_URF': 'cd_urf',
    'NO_VIA': 'cd_via',
    'NO_PAIS': 'cd_pais'
    })
df3.columns = df3.columns.str.strip().str.lower().str.replace(' ', '_')
df4.head()
# Out:
#    cd_unidade sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  vl_frete  \
# 0          11       sc             344          90         6823        77
# 1          11       sp               1           9         4890       147
# 2          10       pe            1128        1128        28129     20688
# 3          10       mg             824         824        66958     11276
# 4          10       sc               3           3         2060        37
#
#    vl_seguro data_importacao  \
# 0         10      2024-10-01
# 1          7      2024-04-01
# 2          7      2024-01-01
# 3         45      2024-06-01
# 4          0      2024-10-01
#
#                                               cd_ncm  \
# 0                                Válvulas solenóides
# 1  Outros instrumentos e aparelhos para telecomun...
# 2     Tubo rígido, de polímeros de cloreto de vinila
# 3  Outros condutores elétricos tensão <= 100 v, c...
# 4                        Outras cabeças de impressão
#
#                                               cd_urf    cd_via  \
# 0                                   0927800 - ITAJAI  MARITIMA
# 1     0817700 - AEROPORTO INTERNACIONAL DE VIRACOPOS     AEREA
# 2  0417901 - IRF - AEROPORTO INTERNACIONAL DOS GU...     AEREA
# 3     0817700 - AEROPORTO INTERNACIONAL DE VIRACOPOS     AEREA
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA
#
#             cd_pais
# 0  Taiwan (Formosa)
# 1    Estados Unidos
# 2          Alemanha
# 3             China
# 4     Coreia do Sul

# %%
#deixando as colunas todas em minúsculas
cols = ['cd_ncm', 'cd_urf', 'cd_via', 'cd_pais']  # Lista das colunas
df4[cols] = df4[cols].apply(lambda x: x.str.strip().str.lower())
df4.head()
# Out:
#    cd_unidade sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  vl_frete  \
# 0          11       sc             344          90         6823        77
# 1          11       sp               1           9         4890       147
# 2          10       pe            1128        1128        28129     20688
# 3          10       mg             824         824        66958     11276
# 4          10       sc               3           3         2060        37
#
#    vl_seguro data_importacao  \
# 0         10      2024-10-01
# 1          7      2024-04-01
# 2          7      2024-01-01
# 3         45      2024-06-01
# 4          0      2024-10-01
#
#                                               cd_ncm  \
# 0                                válvulas solenóides
# 1  outros instrumentos e aparelhos para telecomun...
# 2     tubo rígido, de polímeros de cloreto de vinila
# 3  outros condutores elétricos tensão <= 100 v, c...
# 4                        outras cabeças de impressão
#
#                                               cd_urf    cd_via  \
# 0                                   0927800 - itajai  maritima
# 1     0817700 - aeroporto internacional de viracopos     aerea
# 2  0417901 - irf - aeroporto internacional dos gu...     aerea
# 3     0817700 - aeroporto internacional de viracopos     aerea
# 4  0817600 - aeroporto internacional de sao paulo...     aerea
#
#             cd_pais
# 0  taiwan (formosa)
# 1    estados unidos
# 2          alemanha
# 3             china
# 4     coreia do sul

# %%
caminho = "/home/edcarlos/work_environment/datalake/silver/importacao_2024_m.csv" #salvando as alterações como um novo arquivo
df4.to_csv(caminho, index=False)
print("Arquivo salvo com sucesso!")
# Out:
# Arquivo salvo com sucesso!

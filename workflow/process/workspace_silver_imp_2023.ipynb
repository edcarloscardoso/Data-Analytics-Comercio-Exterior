# %%
import pandas as pd
# Caminho do arquivo
url_imp_2023 = r'\\wsl$\Ubuntu\home\edcarlos\Data-Analytics-Comercio-Exterior\datalake\landing\importacao_2023.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df = pd.read_csv(url_imp_2023, sep=',')
# Exibir as primeiras linhas do DataFrame
df.head()
# Out:
#      cd_ncm  cd_unidade  cd_pais sg_ufncm  cd_via  cd_urf  qt_estatistica  \
# 0  84332010          11      232       sp       1  917800               2
# 1  62129000          11      160       sp       1  817800           33692
# 2  55152200          10      160       es       1  817800             796
# 3  84818099          11      160       go       4  817600             162
# 4  30021235          10      245       sp       4  817600            2444
#
#    kg_liquido  vl_dolarfob  vl_frete  vl_seguro data_importacao_2023
# 0        1970        21899      1075         37           2023-02-01
# 1        3295        29555       453         12           2023-12-01
# 2         796         3985       151          0           2023-01-01
# 3          63         6354       734         12           2023-08-01
# 4        2444      1989352     11233        508           2023-12-01

# %%
# Caminho do arquivo
url_ncm = r'\\wsl$\Ubuntu\home\edcarlos\Data-Analytics-Comercio-Exterior\datalake\raw_data\NCM.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_ncm = pd.read_csv(url_ncm, sep=';', encoding='latin1')
# Exibir as primeiras linhas do DataFrame
df_ncm.head()
# Out:
#      CO_NCM  CO_UNID  CO_SH6  CO_PPE  CO_PPI  CO_FAT_AGREG CO_CUCI_ITEM  \
# 0  49011000       10  490110  3521.0  3521.0           3.0        89215
# 1  49019100       10  490191  3521.0  3521.0           3.0        89216
# 2  49019900       10  490199  3521.0  3521.0           3.0        89219
# 3  49021000       10  490210  3521.0  3521.0           3.0        89221
# 4  52102910       10  521029  3840.0  3840.0           3.0        65251
#
#    CO_CGCE_N3  CO_SIIT  CO_ISIC_CLASSE  CO_EXP_SUBSET  \
# 0         322   9000.0            5811         8099.0
# 1         322   9000.0            5811         8099.0
# 2         322   9000.0            5811         8099.0
# 3         322   9000.0            5813         8099.0
# 4         240   4000.0            1312         1605.0
#
#                                           NO_NCM_POR  \
# 0  Livros, brochuras e impressos semelhantes, em ...
# 1   Dicionários e enciclopédias, mesmo em fascículos
# 2   Outros livros, brochuras e impressos semelhantes
# 3  Jornais e publicações periódicas, impressos, m...
# 4  Tecidos de algodão que contenham menos de 85 %...
#
#                                           NO_NCM_ESP  \
# 0  Libros, folletos, impresos similares, en hojas...
# 1  Diccionarios y enciclopedias, incluso en fascí...
# 2        Otros libros, folletos y impresos similares
# 3  Diarios y publicaciones, impresos, periodo>=4 ...
# 4  Tejidos de algodón, blanqueados, con fibras si...
#
#                                           NO_NCM_ING
# 0  Books, brochures, similar printed papers, in s...
# 1  Dictionaries and encyclopaedias, serial instal...
# 2   Oth.printed books, brochures and similar printed
# 3  Newspapers, journals, printed, periodical>=4 t...
# 4  Fabrics of cotton, bleached, synthetic or arti...

# %%
def carregar_e_mesclar_arquivos(url_imp_2023: str, url_ncm: str, 
                                chave_principal: str, chave_referencia: str, 
                                sep_principal: str = ',', sep_referencia: str = ';', 
                                encoding: str = 'latin1'):
    
    # Carregar os arquivos dentro da função
    df_imp_2023 = pd.read_csv(url_imp_2023, sep=sep_principal, encoding=encoding)
    df_ncm = pd.read_csv(url_ncm, sep=sep_referencia, encoding=encoding)

    # Garantir que as colunas de chave sejam strings
    df_imp_2023[chave_principal] = df_imp_2023[chave_principal].astype(str)
    df_ncm[chave_referencia] = df_ncm[chave_referencia].astype(str)

    # Realizar o merge
    df_resultado = df_imp_2023.merge(df_ncm, left_on=chave_principal, right_on=chave_referencia, how='left')

    return df_resultado

# Exemplo de uso
df_1 = carregar_e_mesclar_arquivos(
    url_imp_2023=r'\\wsl$\Ubuntu\home\edcarlos\Data-Analytics-Comercio-Exterior\datalake\landing\importacao_2023.csv',
    url_ncm=r'\\wsl$\Ubuntu\home\edcarlos\Data-Analytics-Comercio-Exterior\datalake\raw_data\NCM.csv',
    chave_principal='cd_ncm',
    chave_referencia='CO_NCM'
)

# Exibir as primeiras linhas para verificar
df_1.head()
# Out:
#      cd_ncm  cd_unidade  cd_pais sg_ufncm  cd_via  cd_urf  qt_estatistica  \
# 0  84332010          11      232       sp       1  917800               2
# 1  62129000          11      160       sp       1  817800           33692
# 2  55152200          10      160       es       1  817800             796
# 3  84818099          11      160       go       4  817600             162
# 4  30021235          10      245       sp       4  817600            2444
#
#    kg_liquido  vl_dolarfob  vl_frete  ...  CO_PPI CO_FAT_AGREG CO_CUCI_ITEM  \
# 0        1970        21899      1075  ...  3139.0          3.0        72123
# 1        3295        29555       453  ...  3990.0          3.0        84552
# 2         796         3985       151  ...  3851.0          3.0        65341
# 3          63         6354       734  ...  3857.0          3.0         7478
# 4        2444      1989352     11233  ...  3338.0          3.0        54163
#
#    CO_CGCE_N3  CO_SIIT  CO_ISIC_CLASSE  CO_EXP_SUBSET  \
# 0         110   2000.0            2821          906.0
# 1         322   4000.0            1410         1602.0
# 2         240   4000.0            1312         1699.0
# 3         270   2000.0            2813          914.0
# 4         322   1000.0            2100         1406.0
#
#                                           NO_NCM_POR  \
# 0  Ceifeiras, incluindo as barras de corte para m...
# 1  Espartilhos, suspensórios, ligas, artefatos se...
# 2  Tecido de fibras descontínuas acrílicas ou mod...
# 3  Torneiras, e dispositivos semelhantes, para ca...
# 4        Imunoglobulina G, liofilizada ou em solução
#
#                                           NO_NCM_ESP  \
# 0  Guadañadoras c/disp.acond.en hiler.rotor de de...
# 1  Corsés, tirantes, ligas, artículos similares y...
# 2  Tejido de fibras acrílicas, etc.con lana o pel...
# 3  Art.de grifería y demás órganos similares p/tu...
# 4      Inmunoglobulina G, liofilizada, o en solución
#
#                                           NO_NCM_ING
# 0  Mowers with row cond.device consit.fingered ro...
# 1  Corsets, suspenders, gart.similar articles and...
# 2  Fabric of acrylic fibres, etc.with wool/fine a...
# 3           Taps and other appliances for pipes, etc
# 4      Immunoglobulin G, lyophilized, or in solution
#
# [5 rows x 26 columns]

# %%
print(df_1.columns) #verificando todas as colunas do arquivo
# Out:
# Index(['cd_ncm', 'cd_unidade', 'cd_pais', 'sg_ufncm', 'cd_via', 'cd_urf',
#        'qt_estatistica', 'kg_liquido', 'vl_dolarfob', 'vl_frete', 'vl_seguro',
#        'data_importacao_2023', 'CO_NCM', 'CO_UNID', 'CO_SH6', 'CO_PPE',
#        'CO_PPI', 'CO_FAT_AGREG', 'CO_CUCI_ITEM', 'CO_CGCE_N3', 'CO_SIIT',
#        'CO_ISIC_CLASSE', 'CO_EXP_SUBSET', 'NO_NCM_POR', 'NO_NCM_ESP',
#        'NO_NCM_ING'],
#       dtype='object')

# %%
#removendo as colunas que não serão usadas
df_1 = df_1.drop(columns=['cd_ncm', 'CO_NCM', 'CO_UNID', 'CO_SH6', 'CO_PPE', 'CO_PPI', 'CO_FAT_AGREG', 'CO_CUCI_ITEM', 'CO_CGCE_N3', 'CO_SIIT', 'CO_ISIC_CLASSE', 'CO_EXP_SUBSET', 'NO_NCM_ESP', 'NO_NCM_ING'])
df_1.head()
# Out:
#    cd_unidade  cd_pais sg_ufncm  cd_via  cd_urf  qt_estatistica  kg_liquido  \
# 0          11      232       sp       1  917800               2        1970
# 1          11      160       sp       1  817800           33692        3295
# 2          10      160       es       1  817800             796         796
# 3          11      160       go       4  817600             162          63
# 4          10      245       sp       4  817600            2444        2444
#
#    vl_dolarfob  vl_frete  vl_seguro data_importacao_2023  \
# 0        21899      1075         37           2023-02-01
# 1        29555       453         12           2023-12-01
# 2         3985       151          0           2023-01-01
# 3         6354       734         12           2023-08-01
# 4      1989352     11233        508           2023-12-01
#
#                                           NO_NCM_POR
# 0  Ceifeiras, incluindo as barras de corte para m...
# 1  Espartilhos, suspensórios, ligas, artefatos se...
# 2  Tecido de fibras descontínuas acrílicas ou mod...
# 3  Torneiras, e dispositivos semelhantes, para ca...
# 4        Imunoglobulina G, liofilizada ou em solução

# %%
# Caminho do arquivo
url_urf = r'\\wsl$\Ubuntu\home\edcarlos\Data-Analytics-Comercio-Exterior\datalake\raw_data\URF.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_urf = pd.read_csv(url_urf, sep=';',  encoding='latin1')  # Ou tente 'ISO-8859-1'
# Exibir as primeiras linhas do DataFrame
df_urf.head()
# Out:
#    CO_URF                                             NO_URF
# 0     910  0000910 - SEFAZ-SC - CONVENIO CONSULTA SISTEMA...
# 1  110100                                 0110100 - BRASILIA
# 2  117600      0117600 - AEROPORTO INTERNACIONAL DE BRASILIA
# 3  120100                                  0120100 - GOIANIA
# 4  120102                                  0120102 - CATALAO

# %%
# Função para mesclar os DataFrames já carregados
def mesclar_dataframes(df_base: pd.DataFrame, df_referencia: pd.DataFrame, 
                       chave_base: str, chave_referencia: str) -> pd.DataFrame:
    """
    Realiza a junção (merge) entre a base principal e o DataFrame de referência.
    """
    # Garantir que as colunas usadas no merge sejam strings
    df_base[chave_base] = df_base[chave_base].astype(str)
    df_referencia[chave_referencia] = df_referencia[chave_referencia].astype(str)

    # Realizar o merge
    df_resultante = df_base.merge(df_referencia, left_on=chave_base, right_on=chave_referencia, how='left')
    
    return df_resultante

# Exemplo de aplicação da função

# Já carregados anteriormente
# df_1 (base principal) e df_urf (referência) já estão definidos

# Mesclar os DataFrames
df_1 = mesclar_dataframes(df_base=df_1, df_referencia=df_urf, chave_base='cd_urf', chave_referencia='CO_URF')

# Exibir as primeiras linhas do DataFrame resultante
df_1.head()
# Out:
#    cd_unidade  cd_pais sg_ufncm  cd_via  cd_urf  qt_estatistica  kg_liquido  \
# 0          11      232       sp       1  917800               2        1970
# 1          11      160       sp       1  817800           33692        3295
# 2          10      160       es       1  817800             796         796
# 3          11      160       go       4  817600             162          63
# 4          10      245       sp       4  817600            2444        2444
#
#    vl_dolarfob  vl_frete  vl_seguro data_importacao_2023  \
# 0        21899      1075         37           2023-02-01
# 1        29555       453         12           2023-12-01
# 2         3985       151          0           2023-01-01
# 3         6354       734         12           2023-08-01
# 4      1989352     11233        508           2023-12-01
#
#                                           NO_NCM_POR  CO_URF  \
# 0  Ceifeiras, incluindo as barras de corte para m...  917800
# 1  Espartilhos, suspensórios, ligas, artefatos se...  817800
# 2  Tecido de fibras descontínuas acrílicas ou mod...  817800
# 3  Torneiras, e dispositivos semelhantes, para ca...  817600
# 4        Imunoglobulina G, liofilizada ou em solução  817600
#
#                                               NO_URF
# 0                       0917800 - PORTO DE PARANAGUA
# 1                          0817800 - PORTO DE SANTOS
# 2                          0817800 - PORTO DE SANTOS
# 3  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...

# %%
df_1 = df_1.drop(['cd_urf', 'CO_URF'], axis=1) #removendo as colunas com códigos
df_1.head()
# Out:
#    cd_unidade  cd_pais sg_ufncm  cd_via  qt_estatistica  kg_liquido  \
# 0          11      232       sp       1               2        1970
# 1          11      160       sp       1           33692        3295
# 2          10      160       es       1             796         796
# 3          11      160       go       4             162          63
# 4          10      245       sp       4            2444        2444
#
#    vl_dolarfob  vl_frete  vl_seguro data_importacao_2023  \
# 0        21899      1075         37           2023-02-01
# 1        29555       453         12           2023-12-01
# 2         3985       151          0           2023-01-01
# 3         6354       734         12           2023-08-01
# 4      1989352     11233        508           2023-12-01
#
#                                           NO_NCM_POR  \
# 0  Ceifeiras, incluindo as barras de corte para m...
# 1  Espartilhos, suspensórios, ligas, artefatos se...
# 2  Tecido de fibras descontínuas acrílicas ou mod...
# 3  Torneiras, e dispositivos semelhantes, para ca...
# 4        Imunoglobulina G, liofilizada ou em solução
#
#                                               NO_URF
# 0                       0917800 - PORTO DE PARANAGUA
# 1                          0817800 - PORTO DE SANTOS
# 2                          0817800 - PORTO DE SANTOS
# 3  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...

# %%
# Caminho do arquivo
url_via = r'\\wsl$\Ubuntu\home\edcarlos\Data-Analytics-Comercio-Exterior\datalake\raw_data\VIA.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_via = pd.read_csv(url_via, sep=';',  encoding='latin1')  # Ou tente 'ISO-8859-1'
# Exibir as primeiras linhas do DataFrame
df_via.head()
# Out:
#    CO_VIA               NO_VIA
# 0      99     VIA DESCONHECIDA
# 1      13          POR REBOQUE
# 2      11              COURIER
# 3      15  VICINAL FRONTEIRICO
# 4      14                DUTOS

# %%
# Função para mesclar os DataFrames já carregados
def mesclar_dataframes(df_base: pd.DataFrame, df_referencia: pd.DataFrame, 
                       chave_base: str, chave_referencia: str) -> pd.DataFrame:
    """
    Realiza a junção (merge) entre a base principal e o DataFrame de referência.
    """
    # Garantir que as colunas usadas no merge sejam strings
    df_base[chave_base] = df_base[chave_base].astype(str)
    df_referencia[chave_referencia] = df_referencia[chave_referencia].astype(str)

    # Realizar o merge
    df_resultante = df_base.merge(df_referencia, left_on=chave_base, right_on=chave_referencia, how='left')
    
    return df_resultante

# Exemplo de aplicação da função

# Já carregados anteriormente
# df2 (base principal) e df_uf_mun (referência) já estão definidos

# Mesclar os DataFrames
df_2 = mesclar_dataframes(df_base=df_1, df_referencia=df_via, chave_base='cd_via', chave_referencia='CO_VIA')

# Exibir as primeiras linhas do DataFrame resultante
df_2.head()
# Out:
#    cd_unidade  cd_pais sg_ufncm cd_via  qt_estatistica  kg_liquido  \
# 0          11      232       sp      1               2        1970
# 1          11      160       sp      1           33692        3295
# 2          10      160       es      1             796         796
# 3          11      160       go      4             162          63
# 4          10      245       sp      4            2444        2444
#
#    vl_dolarfob  vl_frete  vl_seguro data_importacao_2023  \
# 0        21899      1075         37           2023-02-01
# 1        29555       453         12           2023-12-01
# 2         3985       151          0           2023-01-01
# 3         6354       734         12           2023-08-01
# 4      1989352     11233        508           2023-12-01
#
#                                           NO_NCM_POR  \
# 0  Ceifeiras, incluindo as barras de corte para m...
# 1  Espartilhos, suspensórios, ligas, artefatos se...
# 2  Tecido de fibras descontínuas acrílicas ou mod...
# 3  Torneiras, e dispositivos semelhantes, para ca...
# 4        Imunoglobulina G, liofilizada ou em solução
#
#                                               NO_URF CO_VIA    NO_VIA
# 0                       0917800 - PORTO DE PARANAGUA      1  MARITIMA
# 1                          0817800 - PORTO DE SANTOS      1  MARITIMA
# 2                          0817800 - PORTO DE SANTOS      1  MARITIMA
# 3  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...      4     AEREA
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...      4     AEREA

# %%
df_2 = df_2.drop(['cd_via', 'CO_VIA'], axis=1) #removendo colunas
df_2.head()
# Out:
#    cd_unidade  cd_pais sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  \
# 0          11      232       sp               2        1970        21899
# 1          11      160       sp           33692        3295        29555
# 2          10      160       es             796         796         3985
# 3          11      160       go             162          63         6354
# 4          10      245       sp            2444        2444      1989352
#
#    vl_frete  vl_seguro data_importacao_2023  \
# 0      1075         37           2023-02-01
# 1       453         12           2023-12-01
# 2       151          0           2023-01-01
# 3       734         12           2023-08-01
# 4     11233        508           2023-12-01
#
#                                           NO_NCM_POR  \
# 0  Ceifeiras, incluindo as barras de corte para m...
# 1  Espartilhos, suspensórios, ligas, artefatos se...
# 2  Tecido de fibras descontínuas acrílicas ou mod...
# 3  Torneiras, e dispositivos semelhantes, para ca...
# 4        Imunoglobulina G, liofilizada ou em solução
#
#                                               NO_URF    NO_VIA
# 0                       0917800 - PORTO DE PARANAGUA  MARITIMA
# 1                          0817800 - PORTO DE SANTOS  MARITIMA
# 2                          0817800 - PORTO DE SANTOS  MARITIMA
# 3  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA

# %%
# Caminho do arquivo
url_pais = r'\\wsl$\Ubuntu\home\edcarlos\Data-Analytics-Comercio-Exterior\datalake\raw_data\PAIS.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_pais = pd.read_csv(url_pais, sep=';',  encoding='latin1')  # Ou 'ISO-8859-1'
# Exibir as primeiras linhas do DataFrame
df_pais.head()
# Out:
#    CO_PAIS  CO_PAIS_ISON3 CO_PAIS_ISOA3                 NO_PAIS  \
# 0        0            898           ZZZ            Não Definido
# 1       13              4           AFG             Afeganistão
# 2       15            248           ALA            Aland, Ilhas
# 3       17              8           ALB                 Albânia
# 4       20            724           ESP  Alboran-Perejil, Ilhas
#
#                 NO_PAIS_ING             NO_PAIS_ESP
# 0               Not defined             No definido
# 1               Afghanistan              Afganistan
# 2             Aland Islands            Alans, Islas
# 3                   Albania                 Albania
# 4  Alboran-Perejil, Islands  Alboran-Perejil, Islas

# %%
# Função para mesclar os DataFrames já carregados
def mesclar_dataframes(df_base: pd.DataFrame, df_referencia: pd.DataFrame, 
                       chave_base: str, chave_referencia: str) -> pd.DataFrame:
    """
    Realiza a junção (merge) entre a base principal e o DataFrame de referência.
    """
    # Garantir que as colunas usadas no merge sejam strings
    df_base[chave_base] = df_base[chave_base].astype(str)
    df_referencia[chave_referencia] = df_referencia[chave_referencia].astype(str)

    # Realizar o merge
    df_resultante = df_base.merge(df_referencia, left_on=chave_base, right_on=chave_referencia, how='left')
    
    return df_resultante

# Exemplo de aplicação da função

# Já carregados anteriormente
# df2 (base principal) e df_uf_mun (referência) já estão definidos

# Mesclar os DataFrames
df_3 = mesclar_dataframes(df_base=df_2, df_referencia=df_pais, chave_base='cd_pais', chave_referencia='CO_PAIS')

# Exibir as primeiras linhas do DataFrame resultante
df_3.head()
# Out:
#    cd_unidade cd_pais sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  \
# 0          11     232       sp               2        1970        21899
# 1          11     160       sp           33692        3295        29555
# 2          10     160       es             796         796         3985
# 3          11     160       go             162          63         6354
# 4          10     245       sp            2444        2444      1989352
#
#    vl_frete  vl_seguro data_importacao_2023  \
# 0      1075         37           2023-02-01
# 1       453         12           2023-12-01
# 2       151          0           2023-01-01
# 3       734         12           2023-08-01
# 4     11233        508           2023-12-01
#
#                                           NO_NCM_POR  \
# 0  Ceifeiras, incluindo as barras de corte para m...
# 1  Espartilhos, suspensórios, ligas, artefatos se...
# 2  Tecido de fibras descontínuas acrílicas ou mod...
# 3  Torneiras, e dispositivos semelhantes, para ca...
# 4        Imunoglobulina G, liofilizada ou em solução
#
#                                               NO_URF    NO_VIA CO_PAIS  \
# 0                       0917800 - PORTO DE PARANAGUA  MARITIMA     232
# 1                          0817800 - PORTO DE SANTOS  MARITIMA     160
# 2                          0817800 - PORTO DE SANTOS  MARITIMA     160
# 3  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA     160
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA     245
#
#    CO_PAIS_ISON3 CO_PAIS_ISOA3    NO_PAIS NO_PAIS_ING NO_PAIS_ESP
# 0            208           DNK  Dinamarca     Denmark   Dinamarca
# 1            156           CHN      China       China       China
# 2            156           CHN      China       China       China
# 3            156           CHN      China       China       China
# 4            724           ESP    Espanha       Spain      España

# %%
print(df_3.columns) #verificando as colunas
# Out:
# Index(['cd_unidade', 'cd_pais', 'sg_ufncm', 'qt_estatistica', 'kg_liquido',
#        'vl_dolarfob', 'vl_frete', 'vl_seguro', 'data_importacao_2023',
#        'NO_NCM_POR', 'NO_URF', 'NO_VIA', 'CO_PAIS', 'CO_PAIS_ISON3',
#        'CO_PAIS_ISOA3', 'NO_PAIS', 'NO_PAIS_ING', 'NO_PAIS_ESP'],
#       dtype='object')

# %%
#removendo colunas
df_3 = df_3.drop(columns=['cd_pais', 'CO_PAIS', 'CO_PAIS_ISON3',
       'CO_PAIS_ISOA3', 'NO_PAIS_ING', 'NO_PAIS_ESP'])
df_3.head()
# Out:
#    cd_unidade sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  vl_frete  \
# 0          11       sp               2        1970        21899      1075
# 1          11       sp           33692        3295        29555       453
# 2          10       es             796         796         3985       151
# 3          11       go             162          63         6354       734
# 4          10       sp            2444        2444      1989352     11233
#
#    vl_seguro data_importacao_2023  \
# 0         37           2023-02-01
# 1         12           2023-12-01
# 2          0           2023-01-01
# 3         12           2023-08-01
# 4        508           2023-12-01
#
#                                           NO_NCM_POR  \
# 0  Ceifeiras, incluindo as barras de corte para m...
# 1  Espartilhos, suspensórios, ligas, artefatos se...
# 2  Tecido de fibras descontínuas acrílicas ou mod...
# 3  Torneiras, e dispositivos semelhantes, para ca...
# 4        Imunoglobulina G, liofilizada ou em solução
#
#                                               NO_URF    NO_VIA    NO_PAIS
# 0                       0917800 - PORTO DE PARANAGUA  MARITIMA  Dinamarca
# 1                          0817800 - PORTO DE SANTOS  MARITIMA      China
# 2                          0817800 - PORTO DE SANTOS  MARITIMA      China
# 3  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA      China
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA    Espanha

# %%
# Caminho do arquivo
url_ncm_unidade = r'\\wsl$\Ubuntu\home\edcarlos\Data-Analytics-Comercio-Exterior\datalake\raw_data\NCM_UNIDADE.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_ncm_unidade = pd.read_csv(url_ncm_unidade, sep=';',  encoding='latin1')  # Ou 'ISO-8859-1'
# Exibir as primeiras linhas do DataFrame
df_ncm_unidade.head()
# Out:
#    CO_UNID             NO_UNID SG_UNID
# 0       10  QUILOGRAMA LIQUIDO   KGL
# 1       11    NUMERO (UNIDADE)   UNID.
# 2       12            MILHEIRO   MIL
# 3       13               PARES   PARES
# 4       14               METRO   M

# %%
# Função para mesclar os DataFrames já carregados
def mesclar_dataframes(df_base: pd.DataFrame, df_referencia: pd.DataFrame, 
                       chave_base: str, chave_referencia: str) -> pd.DataFrame:
    """
    Realiza a junção (merge) entre a base principal e o DataFrame de referência.
    """
    # Garantir que as colunas usadas no merge sejam strings
    df_base[chave_base] = df_base[chave_base].astype(str)
    df_referencia[chave_referencia] = df_referencia[chave_referencia].astype(str)

    # Realizar o merge
    df_resultante = df_base.merge(df_referencia, left_on=chave_base, right_on=chave_referencia, how='left')
    
    return df_resultante

# Exemplo de aplicação da função

# Já carregados anteriormente
# df2 (base principal) e df_uf_mun (referência) já estão definidos

# Mesclar os DataFrames
df_4 = mesclar_dataframes(df_base=df_3, df_referencia=df_ncm_unidade, chave_base='cd_unidade', chave_referencia='CO_UNID')

# Exibir as primeiras linhas do DataFrame resultante
df_4.head()
# Out:
#   cd_unidade sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  vl_frete  \
# 0         11       sp               2        1970        21899      1075
# 1         11       sp           33692        3295        29555       453
# 2         10       es             796         796         3985       151
# 3         11       go             162          63         6354       734
# 4         10       sp            2444        2444      1989352     11233
#
#    vl_seguro data_importacao_2023  \
# 0         37           2023-02-01
# 1         12           2023-12-01
# 2          0           2023-01-01
# 3         12           2023-08-01
# 4        508           2023-12-01
#
#                                           NO_NCM_POR  \
# 0  Ceifeiras, incluindo as barras de corte para m...
# 1  Espartilhos, suspensórios, ligas, artefatos se...
# 2  Tecido de fibras descontínuas acrílicas ou mod...
# 3  Torneiras, e dispositivos semelhantes, para ca...
# 4        Imunoglobulina G, liofilizada ou em solução
#
#                                               NO_URF    NO_VIA    NO_PAIS  \
# 0                       0917800 - PORTO DE PARANAGUA  MARITIMA  Dinamarca
# 1                          0817800 - PORTO DE SANTOS  MARITIMA      China
# 2                          0817800 - PORTO DE SANTOS  MARITIMA      China
# 3  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA      China
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA    Espanha
#
#   CO_UNID             NO_UNID SG_UNID
# 0      11    NUMERO (UNIDADE)   UNID.
# 1      11    NUMERO (UNIDADE)   UNID.
# 2      10  QUILOGRAMA LIQUIDO   KGL
# 3      11    NUMERO (UNIDADE)   UNID.
# 4      10  QUILOGRAMA LIQUIDO   KGL

# %%
print(df_4.columns)
# Out:
# Index(['cd_unidade', 'sg_ufncm', 'qt_estatistica', 'kg_liquido', 'vl_dolarfob',
#        'vl_frete', 'vl_seguro', 'data_importacao_2023', 'NO_NCM_POR', 'NO_URF',
#        'NO_VIA', 'NO_PAIS', 'CO_UNID', 'NO_UNID', 'SG_UNID'],
#       dtype='object')

# %%
#removendo colunas
df_4 = df_4.drop(columns=['cd_unidade', 'CO_UNID', 'SG_UNID'])
df_4.head()
# Out:
#   sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  vl_frete  vl_seguro  \
# 0       sp               2        1970        21899      1075         37
# 1       sp           33692        3295        29555       453         12
# 2       es             796         796         3985       151          0
# 3       go             162          63         6354       734         12
# 4       sp            2444        2444      1989352     11233        508
#
#   data_importacao_2023                                         NO_NCM_POR  \
# 0           2023-02-01  Ceifeiras, incluindo as barras de corte para m...
# 1           2023-12-01  Espartilhos, suspensórios, ligas, artefatos se...
# 2           2023-01-01  Tecido de fibras descontínuas acrílicas ou mod...
# 3           2023-08-01  Torneiras, e dispositivos semelhantes, para ca...
# 4           2023-12-01        Imunoglobulina G, liofilizada ou em solução
#
#                                               NO_URF    NO_VIA    NO_PAIS  \
# 0                       0917800 - PORTO DE PARANAGUA  MARITIMA  Dinamarca
# 1                          0817800 - PORTO DE SANTOS  MARITIMA      China
# 2                          0817800 - PORTO DE SANTOS  MARITIMA      China
# 3  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA      China
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA    Espanha
#
#               NO_UNID
# 0    NUMERO (UNIDADE)
# 1    NUMERO (UNIDADE)
# 2  QUILOGRAMA LIQUIDO
# 3    NUMERO (UNIDADE)
# 4  QUILOGRAMA LIQUIDO

# %%
print(df_4.columns)
# Out:
# Index(['sg_ufncm', 'qt_estatistica', 'kg_liquido', 'vl_dolarfob', 'vl_frete',
#        'vl_seguro', 'data_importacao_2023', 'NO_NCM_POR', 'NO_URF', 'NO_VIA',
#        'NO_PAIS', 'NO_UNID'],
#       dtype='object')

# %%
#renomeando colunas
df_4 = df_4.rename(columns={  
    'sg_ufncm': 'sg_ufncm',
    'qt_estatistica': 'qt_estatistica',
    'kg_liquido': 'kg_liquido',
    'vl_dolarfob': 	'vl_dolarfob',
    'vl_frete': 'vl_frete',
    'vl_seguro': 'vl_seguro',
    'data_importacao_2023': 'data_importacao_2023',
    'NO_NCM_POR': 'cd_ncm',
    'NO_URF': 'cd_urf',
    'NO_VIA': 'cd_via',
    'NO_PAIS': 'cd_pais',
    'NO_UNID': 'cd_unidade'
    })
df_4.columns = df_4.columns.str.strip().str.lower().str.replace(' ', '_')
df_4.head()
# Out:
#   sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  vl_frete  vl_seguro  \
# 0       sp               2        1970        21899      1075         37
# 1       sp           33692        3295        29555       453         12
# 2       es             796         796         3985       151          0
# 3       go             162          63         6354       734         12
# 4       sp            2444        2444      1989352     11233        508
#
#   data_importacao_2023                                             cd_ncm  \
# 0           2023-02-01  Ceifeiras, incluindo as barras de corte para m...
# 1           2023-12-01  Espartilhos, suspensórios, ligas, artefatos se...
# 2           2023-01-01  Tecido de fibras descontínuas acrílicas ou mod...
# 3           2023-08-01  Torneiras, e dispositivos semelhantes, para ca...
# 4           2023-12-01        Imunoglobulina G, liofilizada ou em solução
#
#                                               cd_urf    cd_via    cd_pais  \
# 0                       0917800 - PORTO DE PARANAGUA  MARITIMA  Dinamarca
# 1                          0817800 - PORTO DE SANTOS  MARITIMA      China
# 2                          0817800 - PORTO DE SANTOS  MARITIMA      China
# 3  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA      China
# 4  0817600 - AEROPORTO INTERNACIONAL DE SAO PAULO...     AEREA    Espanha
#
#            cd_unidade
# 0    NUMERO (UNIDADE)
# 1    NUMERO (UNIDADE)
# 2  QUILOGRAMA LIQUIDO
# 3    NUMERO (UNIDADE)
# 4  QUILOGRAMA LIQUIDO

# %%
def padronizar_colunas(df, colunas):
    """
    Remove espaços extras e converte os valores das colunas especificadas para minúsculas.

    Parâmetros:
        df (pd.DataFrame): DataFrame de entrada.
        colunas (list): Lista de colunas a serem padronizadas.

    Retorna:
        pd.DataFrame: DataFrame com as colunas padronizadas.
    """
    df[colunas] = df[colunas].apply(lambda x: x.str.strip().str.lower())
    return df

df_4 = padronizar_colunas(df_4, ['cd_ncm', 'cd_urf', 'cd_via', 'cd_pais', 'cd_unidade'])
df_4.head()
# Out:
#   sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  vl_frete  vl_seguro  \
# 0       sp               2        1970        21899      1075         37
# 1       sp           33692        3295        29555       453         12
# 2       es             796         796         3985       151          0
# 3       go             162          63         6354       734         12
# 4       sp            2444        2444      1989352     11233        508
#
#   data_importacao_2023                                             cd_ncm  \
# 0           2023-02-01  ceifeiras, incluindo as barras de corte para m...
# 1           2023-12-01  espartilhos, suspensórios, ligas, artefatos se...
# 2           2023-01-01  tecido de fibras descontínuas acrílicas ou mod...
# 3           2023-08-01  torneiras, e dispositivos semelhantes, para ca...
# 4           2023-12-01        imunoglobulina g, liofilizada ou em solução
#
#                                               cd_urf    cd_via    cd_pais  \
# 0                       0917800 - porto de paranagua  maritima  dinamarca
# 1                          0817800 - porto de santos  maritima      china
# 2                          0817800 - porto de santos  maritima      china
# 3  0817600 - aeroporto internacional de sao paulo...     aerea      china
# 4  0817600 - aeroporto internacional de sao paulo...     aerea    espanha
#
#            cd_unidade
# 0    numero (unidade)
# 1    numero (unidade)
# 2  quilograma liquido
# 3    numero (unidade)
# 4  quilograma liquido

# %%
caminho = "/home/edcarlos/Data-Analytics-Comercio-Exterior/datalake/silver/importacao_2023_m.csv" #salvando o arquivo
df_4.to_csv(caminho, index=False)
print("Arquivo salvo com sucesso!")
# Out:
# Arquivo salvo com sucesso!

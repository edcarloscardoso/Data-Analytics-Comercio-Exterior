# %%
import pandas as pd
# Caminho do arquivo
caminho_arquivo = r'\\wsl$\Ubuntu\home\edcarlos\work_environment\datalake\bronze\importacao_2023.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df = pd.read_csv(caminho_arquivo, sep=',')
# Exibir as primeiras linhas do DataFrame
df.head()
# Out:
#      cd_ncm  cd_unidade  cd_pais sg_ufncm  cd_via  cd_urf  qt_estatistica  \
# 0  84332010          11      232       sp       1  917800               2
# 1  62129000          11      160       sp       1  817800           33692
# 2  55152200          10      160       es       1  817800             796
# 3  84818099          11      160       go       4  817600             162
# 4  30021235          10      245       sp       4  817600            2444
#
#    kg_liquido  vl_dolarfob  vl_frete  vl_seguro data_importacao_2023
# 0        1970        21899      1075         37           2023-02-01
# 1        3295        29555       453         12           2023-12-01
# 2         796         3985       151          0           2023-01-01
# 3          63         6354       734         12           2023-08-01
# 4        2444      1989352     11233        508           2023-12-01

# %%
# Caminho do arquivo
arquivo_ncm = r'\\wsl$\Ubuntu\home\edcarlos\work_environment\datalake\landing\NCM.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_ncm = pd.read_csv(arquivo_ncm, sep=';', encoding='latin1')
# Exibir as primeiras linhas do DataFrame
df.head()
# Out:
#      cd_ncm  cd_unidade  cd_pais sg_ufncm  cd_via  cd_urf  qt_estatistica  \
# 0  84332010          11      232       sp       1  917800               2
# 1  62129000          11      160       sp       1  817800           33692
# 2  55152200          10      160       es       1  817800             796
# 3  84818099          11      160       go       4  817600             162
# 4  30021235          10      245       sp       4  817600            2444
#
#    kg_liquido  vl_dolarfob  vl_frete  vl_seguro data_importacao_2023
# 0        1970        21899      1075         37           2023-02-01
# 1        3295        29555       453         12           2023-12-01
# 2         796         3985       151          0           2023-01-01
# 3          63         6354       734         12           2023-08-01
# 4        2444      1989352     11233        508           2023-12-01

# %%
# Carregar o arquivo principal que contém a coluna cd_ncm
df = pd.read_csv(caminho_arquivo, sep=',', encoding='latin1')

# Carregar o arquivo que contém a coluna CO_NCM
df_ncm = pd.read_csv(arquivo_ncm, sep=';', encoding='latin1')

# Garantir que cd_ncm seja string
df['cd_ncm'] = df['cd_ncm'].astype(str)

# Garantir que CO_NCM seja string
df_ncm['CO_NCM'] = df_ncm['CO_NCM'].astype(str)

# Fazer o merge para substituir os códigos pelos nomes dos países
df = df.merge(df_ncm, left_on='cd_ncm', right_on='CO_NCM', how='left')

# Exibir as primeiras linhas para verificar se deu certo
df.head()
# Out:
#      cd_ncm  cd_unidade  cd_pais sg_ufncm  cd_via  cd_urf  qt_estatistica  \
# 0  84332010          11      232       sp       1  917800               2
# 1  62129000          11      160       sp       1  817800           33692
# 2  55152200          10      160       es       1  817800             796
# 3  84818099          11      160       go       4  817600             162
# 4  30021235          10      245       sp       4  817600            2444
#
#    kg_liquido  vl_dolarfob  vl_frete  ...  CO_PPI CO_FAT_AGREG CO_CUCI_ITEM  \
# 0        1970        21899      1075  ...  3139.0          3.0        72123
# 1        3295        29555       453  ...  3990.0          3.0        84552
# 2         796         3985       151  ...  3851.0          3.0        65341
# 3          63         6354       734  ...  3857.0          3.0         7478
# 4        2444      1989352     11233  ...  3338.0          3.0        54163
#
#    CO_CGCE_N3  CO_SIIT  CO_ISIC_CLASSE  CO_EXP_SUBSET  \
# ...

# %%
print(df.columns) #verificando todas as colunas do arquivo
# Out:
# Index(['cd_ncm', 'cd_unidade', 'cd_pais', 'sg_ufncm', 'cd_via', 'cd_urf',
#        'qt_estatistica', 'kg_liquido', 'vl_dolarfob', 'vl_frete', 'vl_seguro',
#        'data_importacao_2023', 'CO_NCM', 'CO_UNID', 'CO_SH6', 'CO_PPE',
#        'CO_PPI', 'CO_FAT_AGREG', 'CO_CUCI_ITEM', 'CO_CGCE_N3', 'CO_SIIT',
#        'CO_ISIC_CLASSE', 'CO_EXP_SUBSET', 'NO_NCM_POR', 'NO_NCM_ESP',
#        'NO_NCM_ING'],
#       dtype='object')

# %%
#removendo as colunas que não serão usadas
df = df.drop(columns=['cd_ncm', 'CO_NCM', 'CO_UNID', 'CO_SH6', 'CO_PPE', 'CO_PPI', 'CO_FAT_AGREG', 'CO_CUCI_ITEM', 'CO_CGCE_N3', 'CO_SIIT', 'CO_ISIC_CLASSE', 'CO_EXP_SUBSET', 'NO_NCM_ESP', 'NO_NCM_ING'])
df.head()
# Out:
#    cd_unidade  cd_pais sg_ufncm  cd_via  cd_urf  qt_estatistica  kg_liquido  \
# 0          11      232       sp       1  917800               2        1970
# 1          11      160       sp       1  817800           33692        3295
# 2          10      160       es       1  817800             796         796
# 3          11      160       go       4  817600             162          63
# 4          10      245       sp       4  817600            2444        2444
#
#    vl_dolarfob  vl_frete  vl_seguro data_importacao_2023  \
# 0        21899      1075         37           2023-02-01
# 1        29555       453         12           2023-12-01
# 2         3985       151          0           2023-01-01
# 3         6354       734         12           2023-08-01
# 4      1989352     11233        508           2023-12-01
#
#                                           NO_NCM_POR
# 0  Ceifeiras, incluindo as barras de corte para m...
# 1  Espartilhos, suspensórios, ligas, artefatos se...
# ...

# %%
# Caminho do arquivo
arquivo_urf = r'\\wsl$\Ubuntu\home\edcarlos\work_environment\datalake\landing\URF.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_urf = pd.read_csv(arquivo_urf, sep=';',  encoding='latin1')  # Ou tente 'ISO-8859-1'
# Exibir as primeiras linhas do DataFrame
df_urf.head()
# Out:
#    CO_URF                                             NO_URF
# 0     910  0000910 - SEFAZ-SC - CONVENIO CONSULTA SISTEMA...
# 1  110100                                 0110100 - BRASILIA
# 2  117600      0117600 - AEROPORTO INTERNACIONAL DE BRASILIA
# 3  120100                                  0120100 - GOIANIA
# 4  120102                                  0120102 - CATALAO

# %%
# Garantir que cd_urf e CO_URF sejam do mesmo tipo
df1 = df['cd_urf'] = df['cd_urf'].astype(str)
df_urf['CO_URF'] = df_urf['CO_URF'].astype(str)

# Fazer o merge para substituir os códigos pelos nomes das URFs
df1 = df.merge(df_urf, left_on='cd_urf', right_on='CO_URF', how='left')

# Exibir as primeiras linhas para verificar se deu certo
df1.head()
# Out:
#    cd_unidade  cd_pais sg_ufncm  cd_via  cd_urf  qt_estatistica  kg_liquido  \
# 0          11      232       sp       1  917800               2        1970
# 1          11      160       sp       1  817800           33692        3295
# 2          10      160       es       1  817800             796         796
# 3          11      160       go       4  817600             162          63
# 4          10      245       sp       4  817600            2444        2444
#
#    vl_dolarfob  vl_frete  vl_seguro data_importacao_2023  \
# 0        21899      1075         37           2023-02-01
# 1        29555       453         12           2023-12-01
# 2         3985       151          0           2023-01-01
# 3         6354       734         12           2023-08-01
# 4      1989352     11233        508           2023-12-01
#
#                                           NO_NCM_POR  CO_URF  \
# 0  Ceifeiras, incluindo as barras de corte para m...  917800
# ...

# %%
df1 = df1.drop(['cd_urf', 'CO_URF'], axis=1) #removendo as colunas com códigos
df1.head()
# Out:
#    cd_unidade  cd_pais sg_ufncm  cd_via  qt_estatistica  kg_liquido  \
# 0          11      232       sp       1               2        1970
# 1          11      160       sp       1           33692        3295
# 2          10      160       es       1             796         796
# 3          11      160       go       4             162          63
# 4          10      245       sp       4            2444        2444
#
#    vl_dolarfob  vl_frete  vl_seguro data_importacao_2023  \
# 0        21899      1075         37           2023-02-01
# 1        29555       453         12           2023-12-01
# 2         3985       151          0           2023-01-01
# 3         6354       734         12           2023-08-01
# 4      1989352     11233        508           2023-12-01
#
#                                           NO_NCM_POR  \
# 0  Ceifeiras, incluindo as barras de corte para m...
# 1  Espartilhos, suspensórios, ligas, artefatos se...
# ...

# %%
# Caminho do arquivo
arquivo_via = r'\\wsl$\Ubuntu\home\edcarlos\work_environment\datalake\landing\VIA.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_via = pd.read_csv(arquivo_via, sep=';',  encoding='latin1')  # Ou tente 'ISO-8859-1'
# Exibir as primeiras linhas do DataFrame
df_via.head()
# Out:
#    CO_VIA               NO_VIA
# 0      99     VIA DESCONHECIDA
# 1      13          POR REBOQUE
# 2      11              COURIER
# 3      15  VICINAL FRONTEIRICO
# 4      14                DUTOS

# %%
# Garantir que cd_via e CO_VIA sejam do mesmo tipo
df2 = df1['cd_via'] = df['cd_via'].astype(str)
df_via['CO_VIA'] = df_via['CO_VIA'].astype(str)

# Fazer o merge para substituir os códigos pelos nomes das VIAs
df2 = df1.merge(df_via, left_on='cd_via', right_on='CO_VIA', how='left')

# Exibir as primeiras linhas para verificar se deu certo
df2.head()
# Out:
#    cd_unidade  cd_pais sg_ufncm cd_via  qt_estatistica  kg_liquido  \
# 0          11      232       sp      1               2        1970
# 1          11      160       sp      1           33692        3295
# 2          10      160       es      1             796         796
# 3          11      160       go      4             162          63
# 4          10      245       sp      4            2444        2444
#
#    vl_dolarfob  vl_frete  vl_seguro data_importacao_2023  \
# 0        21899      1075         37           2023-02-01
# 1        29555       453         12           2023-12-01
# 2         3985       151          0           2023-01-01
# 3         6354       734         12           2023-08-01
# 4      1989352     11233        508           2023-12-01
#
#                                           NO_NCM_POR  \
# 0  Ceifeiras, incluindo as barras de corte para m...
# 1  Espartilhos, suspensórios, ligas, artefatos se...
# ...

# %%
df2 = df2.drop(['cd_via', 'CO_VIA'], axis=1) #removendo colunas
df2.head()
# Out:
#    cd_unidade  cd_pais sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  \
# 0          11      232       sp               2        1970        21899
# 1          11      160       sp           33692        3295        29555
# 2          10      160       es             796         796         3985
# 3          11      160       go             162          63         6354
# 4          10      245       sp            2444        2444      1989352
#
#    vl_frete  vl_seguro data_importacao_2023  \
# 0      1075         37           2023-02-01
# 1       453         12           2023-12-01
# 2       151          0           2023-01-01
# 3       734         12           2023-08-01
# 4     11233        508           2023-12-01
#
#                                           NO_NCM_POR  \
# 0  Ceifeiras, incluindo as barras de corte para m...
# 1  Espartilhos, suspensórios, ligas, artefatos se...
# 2  Tecido de fibras descontínuas acrílicas ou mod...
# ...

# %%
# Caminho do arquivo
arquivo_pais = r'\\wsl$\Ubuntu\home\edcarlos\work_environment\datalake\landing\PAIS.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_pais = pd.read_csv(arquivo_pais, sep=';',  encoding='latin1')  # Ou 'ISO-8859-1'
# Exibir as primeiras linhas do DataFrame
df_pais.head()
# Out:
#    CO_PAIS  CO_PAIS_ISON3 CO_PAIS_ISOA3                 NO_PAIS  \
# 0        0            898           ZZZ            Não Definido
# 1       13              4           AFG             Afeganistão
# 2       15            248           ALA            Aland, Ilhas
# 3       17              8           ALB                 Albânia
# 4       20            724           ESP  Alboran-Perejil, Ilhas
#
#                 NO_PAIS_ING             NO_PAIS_ESP
# 0               Not defined             No definido
# 1               Afghanistan              Afganistan
# 2             Aland Islands            Alans, Islas
# 3                   Albania                 Albania
# 4  Alboran-Perejil, Islands  Alboran-Perejil, Islas

# %%
# Garantir que cd_urf e CO_URF sejam do mesmo tipo
df3 = df2['cd_pais'] = df['cd_pais'].astype(str)
df_pais['CO_PAIS'] = df_pais['CO_PAIS'].astype(str)

# Fazer o merge para substituir os códigos pelos nomes dos países
df3 = df2.merge(df_pais, left_on='cd_pais', right_on='CO_PAIS', how='left')

# Exibir as primeiras linhas para verificar se deu certo
df3.head()
# Out:
#    cd_unidade cd_pais sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  \
# 0          11     232       sp               2        1970        21899
# 1          11     160       sp           33692        3295        29555
# 2          10     160       es             796         796         3985
# 3          11     160       go             162          63         6354
# 4          10     245       sp            2444        2444      1989352
#
#    vl_frete  vl_seguro data_importacao_2023  \
# 0      1075         37           2023-02-01
# 1       453         12           2023-12-01
# 2       151          0           2023-01-01
# 3       734         12           2023-08-01
# 4     11233        508           2023-12-01
#
#                                           NO_NCM_POR  \
# 0  Ceifeiras, incluindo as barras de corte para m...
# 1  Espartilhos, suspensórios, ligas, artefatos se...
# 2  Tecido de fibras descontínuas acrílicas ou mod...
# ...

# %%
print(df3.columns) #verificando as colunas
# Out:
# Index(['cd_unidade', 'cd_pais', 'sg_ufncm', 'qt_estatistica', 'kg_liquido',
#        'vl_dolarfob', 'vl_frete', 'vl_seguro', 'data_importacao_2023',
#        'NO_NCM_POR', 'NO_URF', 'NO_VIA', 'CO_PAIS', 'CO_PAIS_ISON3',
#        'CO_PAIS_ISOA3', 'NO_PAIS', 'NO_PAIS_ING', 'NO_PAIS_ESP'],
#       dtype='object')

# %%
#removendo colunas
df3 = df3.drop(columns=['cd_pais', 'CO_PAIS', 'CO_PAIS_ISON3',
       'CO_PAIS_ISOA3', 'NO_PAIS_ING', 'NO_PAIS_ESP'])
df3.head()
# Out:
#    cd_unidade sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  vl_frete  \
# 0          11       sp               2        1970        21899      1075
# 1          11       sp           33692        3295        29555       453
# 2          10       es             796         796         3985       151
# 3          11       go             162          63         6354       734
# 4          10       sp            2444        2444      1989352     11233
#
#    vl_seguro data_importacao_2023  \
# 0         37           2023-02-01
# 1         12           2023-12-01
# 2          0           2023-01-01
# 3         12           2023-08-01
# 4        508           2023-12-01
#
#                                           NO_NCM_POR  \
# 0  Ceifeiras, incluindo as barras de corte para m...
# 1  Espartilhos, suspensórios, ligas, artefatos se...
# 2  Tecido de fibras descontínuas acrílicas ou mod...
# 3  Torneiras, e dispositivos semelhantes, para ca...
# ...

# %%
print(df3.columns)
# Out:
# Index(['cd_unidade', 'sg_ufncm', 'qt_estatistica', 'kg_liquido', 'vl_dolarfob',
#        'vl_frete', 'vl_seguro', 'data_importacao_2023', 'NO_NCM_POR', 'NO_URF',
#        'NO_VIA', 'NO_PAIS'],
#       dtype='object')

# %%
#renomeando colunas
df4 = df3.rename(columns={  
    'cd_unidade': 'cd_unidade',
    'sg_ufncm': 'sg_ufncm',
    'qt_estatistica': 'qt_estatistica',
    'kg_liquido': 'kg_liquido',
    'vl_dolarfob': 	'vl_dolarfob',
    'vl_frete': 'vl_frete',
    'vl_seguro': 'vl_seguro',
    'data_importacao_2023': 'data_importacao_2023',
    'NO_NCM_POR': 'cd_ncm',
    'NO_URF': 'cd_urf',
    'NO_VIA': 'cd_via',
    'NO_PAIS': 'cd_pais'
    })
df3.columns = df3.columns.str.strip().str.lower().str.replace(' ', '_')
df4.head()
# Out:
#    cd_unidade sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  vl_frete  \
# 0          11       sp               2        1970        21899      1075
# 1          11       sp           33692        3295        29555       453
# 2          10       es             796         796         3985       151
# 3          11       go             162          63         6354       734
# 4          10       sp            2444        2444      1989352     11233
#
#    vl_seguro data_importacao_2023  \
# 0         37           2023-02-01
# 1         12           2023-12-01
# 2          0           2023-01-01
# 3         12           2023-08-01
# 4        508           2023-12-01
#
#                                               cd_ncm  \
# 0  Ceifeiras, incluindo as barras de corte para m...
# 1  Espartilhos, suspensórios, ligas, artefatos se...
# 2  Tecido de fibras descontínuas acrílicas ou mod...
# 3  Torneiras, e dispositivos semelhantes, para ca...
# ...

# %%
cols = ['cd_ncm', 'cd_urf', 'cd_via', 'cd_pais']  # Lista das colunas
df4[cols] = df4[cols].apply(lambda x: x.str.strip().str.lower()) #deixando tudo minúsculo
df4.head()
# Out:
#    cd_unidade sg_ufncm  qt_estatistica  kg_liquido  vl_dolarfob  vl_frete  \
# 0          11       sp               2        1970        21899      1075
# 1          11       sp           33692        3295        29555       453
# 2          10       es             796         796         3985       151
# 3          11       go             162          63         6354       734
# 4          10       sp            2444        2444      1989352     11233
#
#    vl_seguro data_importacao_2023  \
# 0         37           2023-02-01
# 1         12           2023-12-01
# 2          0           2023-01-01
# 3         12           2023-08-01
# 4        508           2023-12-01
#
#                                               cd_ncm  \
# 0  ceifeiras, incluindo as barras de corte para m...
# 1  espartilhos, suspensórios, ligas, artefatos se...
# 2  tecido de fibras descontínuas acrílicas ou mod...
# 3  torneiras, e dispositivos semelhantes, para ca...
# ...

# %%
caminho = "/home/edcarlos/work_environment/datalake/silver/importacao_2023_m.csv" #salvando o arquivo
df4.to_csv(caminho, index=False)
print("Arquivo salvo com sucesso!")
# Out:
# Arquivo salvo com sucesso!

# %%
import pandas as pd
# Caminho do arquivo
arquivo_imp_mun_2024 = r'\\wsl$\Ubuntu\home\edcarlos\work_environment\datalake\landing\importacao_mun_2024.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df = pd.read_csv(arquivo_imp_mun_2024, sep=',')
# Exibir as primeiras linhas do DataFrame
df.head()
# Out:
#    cd_sh4  cd_pais sg_ufmun   cd_mun  kg_liquido  vl_dolarfob  \
# 0    3204      361       rs  4311809        7000        26243
# 1    7318      386       rj  3302403          34         3037
# 2    8482      160       am  1302603       31357       325347
# 3    8483      399       am  1302603       52751      1146340
# 4    8483      573       rj  3303302         207        68982
#
#   data_importacao_mun
# 0          2024-12-01
# 1          2024-02-01
# 2          2024-12-01
# 3          2024-01-01
# 4          2024-03-01

# %%
# Caminho do arquivo
arquivo_ncm = r'\\wsl$\Ubuntu\home\edcarlos\work_environment\datalake\raw_data\NCM_SH.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_ncm = pd.read_csv(arquivo_ncm, sep=';', encoding='latin1')
# Exibir as primeiras linhas do DataFrame
df_ncm.head()
# Out:
#    CO_SH6                                         NO_SH6_POR  \
# 0   10110  Animais vivos das espécies cavalar, asinina e ...
# 1   10111                 Cavalos reprodutores, de raça pura
# 2   10119                              Outros cavalos, vivos
# 3   10120                            Asininos e muares vivos
# 4   10121                  Cavalos reprodutores de raça pura
#
#                                      NO_SH6_ESP  \
# 0  Caballos y asnos, reproductores de raza pura
# 1           Caballos reproductores de raza pura
# 2                         Demás caballos, vivos
# 3              Asnos, mulos y burdéganos, vivos
# 4    Caballos de raza selecta para reproducción
#
#                             NO_SH6_ING  CO_SH4  \
# 0  Pure-bred breeding horses and asses     101
# 1            Pure-bred breeding horses     101
# 2                    Other live horses     101
# 3      Asses, mules and hinnies (live)     101
# 4            Pure-bred breeding horses     101
#
#                           NO_SH4_POR  \
# 0  Cavalos, asininos e muares, vivos
# 1  Cavalos, asininos e muares, vivos
# 2  Cavalos, asininos e muares, vivos
# 3  Cavalos, asininos e muares, vivos
# 4  Cavalos, asininos e muares, vivos
#
#                                    NO_SH4_ESP  \
# 0  Caballos, asnos, mulos y burdéganos, vivos
# 1  Caballos, asnos, mulos y burdéganos, vivos
# 2  Caballos, asnos, mulos y burdéganos, vivos
# 3  Caballos, asnos, mulos y burdéganos, vivos
# 4  Caballos, asnos, mulos y burdéganos, vivos
#
#                               NO_SH4_ING  CO_SH2     NO_SH2_POR  \
# 0  Live horses, asses, mules and hinnies       1  Animais vivos
# 1  Live horses, asses, mules and hinnies       1  Animais vivos
# 2  Live horses, asses, mules and hinnies       1  Animais vivos
# 3  Live horses, asses, mules and hinnies       1  Animais vivos
# 4  Live horses, asses, mules and hinnies       1  Animais vivos
#
#        NO_SH2_ESP    NO_SH2_ING CO_NCM_SECROM  \
# 0  Animales vivos  Live animals             I
# 1  Animales vivos  Live animals             I
# 2  Animales vivos  Live animals             I
# 3  Animales vivos  Live animals             I
# 4  Animales vivos  Live animals             I
#
#                                  NO_SEC_POR  \
# 0  Animais vivos e produtos do reino animal
# 1  Animais vivos e produtos do reino animal
# 2  Animais vivos e produtos do reino animal
# 3  Animais vivos e produtos do reino animal
# 4  Animais vivos e produtos do reino animal
#
#                                     NO_SEC_ESP                      NO_SEC_ING
# 0  Animales vivos y productos del reino animal  Lives animals; Animal products
# 1  Animales vivos y productos del reino animal  Lives animals; Animal products
# 2  Animales vivos y productos del reino animal  Lives animals; Animal products
# 3  Animales vivos y productos del reino animal  Lives animals; Animal products
# 4  Animales vivos y productos del reino animal  Lives animals; Animal products

# %%
# Carregar o arquivo principal que contém a coluna cd_ncm
df = pd.read_csv(arquivo_imp_mun_2024, sep=',', encoding='latin1')

# Carregar o arquivo que contém a coluna CO_NCM
df_ncm = pd.read_csv(arquivo_ncm, sep=';', encoding='latin1')

# Garantir que cd_ncm seja string
df['cd_sh4'] = df['cd_sh4'].astype(str)

# Garantir que CO_NCM seja string
df_ncm['CO_SH4'] = df_ncm['CO_SH4'].astype(str)

# Fazer o merge para substituir os códigos pelos nomes dos países
df = df.merge(df_ncm, left_on='cd_sh4', right_on='CO_SH4', how='left')

# Exibir as primeiras linhas para verificar se deu certo
df.head()
# Out:
#   cd_sh4  cd_pais sg_ufmun   cd_mun  kg_liquido  vl_dolarfob  \
# 0   3204      361       rs  4311809        7000        26243
# 1   3204      361       rs  4311809        7000        26243
# 2   3204      361       rs  4311809        7000        26243
# 3   3204      361       rs  4311809        7000        26243
# 4   3204      361       rs  4311809        7000        26243
#
#   data_importacao_mun  CO_SH6  \
# 0          2024-12-01  320411
# 1          2024-12-01  320412
# 2          2024-12-01  320413
# 3          2024-12-01  320414
# 4          2024-12-01  320415
#
#                                           NO_SH6_POR  \
# 0  Corantes orgânico-sintéticos dispersos e suas ...
# 1  Corantes ácidos, mesmo metalizados e suas prep...
# 2                Corantes básicos e suas preparações
# 3                Corantes diretos e suas preparações
# 4                 Corantes à cuba e suas preparações
#
#                                           NO_SH6_ESP  ...  \
# 0  Colorantes dispersos sintéticos orgánicos; pre...  ...
# 1  Colorantes ácidos sintéticos orgánicos, incl. ...  ...
# 2  Colorantes básicos sintéticos orgánicos; prepa...  ...
# 3  Colorantes directos sintéticos orgánicos; prep...  ...
# 4  Colorantes sintéticos orgánicos a la tina o a ...  ...
#
#                                           NO_SH4_ESP  \
# 0  Materias colorantes orgánicas sintéticas, aunq...
# 1  Materias colorantes orgánicas sintéticas, aunq...
# 2  Materias colorantes orgánicas sintéticas, aunq...
# 3  Materias colorantes orgánicas sintéticas, aunq...
# 4  Materias colorantes orgánicas sintéticas, aunq...
#
#                                           NO_SH4_ING CO_SH2  \
# 0  Synthetic organic colouring matter, whether or...     32
# 1  Synthetic organic colouring matter, whether or...     32
# 2  Synthetic organic colouring matter, whether or...     32
# 3  Synthetic organic colouring matter, whether or...     32
# 4  Synthetic organic colouring matter, whether or...     32
#
#                                           NO_SH2_POR  \
# 0  Extratos tanantes e tintoriais; taninos e seus...
# 1  Extratos tanantes e tintoriais; taninos e seus...
# 2  Extratos tanantes e tintoriais; taninos e seus...
# 3  Extratos tanantes e tintoriais; taninos e seus...
# 4  Extratos tanantes e tintoriais; taninos e seus...
#
#                                           NO_SH2_ESP  \
# 0  Extractos curtientes o tintóreos; taninos y su...
# 1  Extractos curtientes o tintóreos; taninos y su...
# 2  Extractos curtientes o tintóreos; taninos y su...
# 3  Extractos curtientes o tintóreos; taninos y su...
# 4  Extractos curtientes o tintóreos; taninos y su...
#
#                                           NO_SH2_ING CO_NCM_SECROM  \
# 0  Tanning or dyeing extracts; tannins and their ...            VI
# 1  Tanning or dyeing extracts; tannins and their ...            VI
# 2  Tanning or dyeing extracts; tannins and their ...            VI
# 3  Tanning or dyeing extracts; tannins and their ...            VI
# 4  Tanning or dyeing extracts; tannins and their ...            VI
#
#                                           NO_SEC_POR  \
# 0  Produtos das indústrias químicas ou indústrias...
# 1  Produtos das indústrias químicas ou indústrias...
# 2  Produtos das indústrias químicas ou indústrias...
# 3  Produtos das indústrias químicas ou indústrias...
# 4  Produtos das indústrias químicas ou indústrias...
#
#                                           NO_SEC_ESP  \
# 0  Productos de las industrias químicas o de las ...
# 1  Productos de las industrias químicas o de las ...
# 2  Productos de las industrias químicas o de las ...
# 3  Productos de las industrias químicas o de las ...
# 4  Productos de las industrias químicas o de las ...
#
#                                       NO_SEC_ING
# 0  Products of the chemical or allied industries
# 1  Products of the chemical or allied industries
# 2  Products of the chemical or allied industries
# 3  Products of the chemical or allied industries
# 4  Products of the chemical or allied industries
#
# [5 rows x 23 columns]

# %%
print(df.columns)
# Out:
# Index(['cd_sh4', 'cd_pais', 'sg_ufmun', 'cd_mun', 'kg_liquido', 'vl_dolarfob',
#        'data_importacao_mun', 'CO_SH6', 'NO_SH6_POR', 'NO_SH6_ESP',
#        'NO_SH6_ING', 'CO_SH4', 'NO_SH4_POR', 'NO_SH4_ESP', 'NO_SH4_ING',
#        'CO_SH2', 'NO_SH2_POR', 'NO_SH2_ESP', 'NO_SH2_ING', 'CO_NCM_SECROM',
#        'NO_SEC_POR', 'NO_SEC_ESP', 'NO_SEC_ING'],
#       dtype='object')

# %%
df = df.drop(columns=['cd_sh4', 'CO_SH6', 'NO_SH6_POR', 'NO_SH6_ESP',
       'NO_SH6_ING', 'CO_SH4', 'NO_SH4_ESP', 'NO_SH4_ING',
       'CO_SH2', 'NO_SH2_POR', 'NO_SH2_ESP', 'NO_SH2_ING', 'CO_NCM_SECROM',
       'NO_SEC_POR', 'NO_SEC_ESP', 'NO_SEC_ING'])
df.head()
# Out:
#    cd_pais sg_ufmun   cd_mun  kg_liquido  vl_dolarfob data_importacao_mun  \
# 0      361       rs  4311809        7000        26243          2024-12-01
# 1      361       rs  4311809        7000        26243          2024-12-01
# 2      361       rs  4311809        7000        26243          2024-12-01
# 3      361       rs  4311809        7000        26243          2024-12-01
# 4      361       rs  4311809        7000        26243          2024-12-01
#
#                                           NO_SH4_POR
# 0  Matérias corantes orgânicas sintéticas, mesmo ...
# 1  Matérias corantes orgânicas sintéticas, mesmo ...
# 2  Matérias corantes orgânicas sintéticas, mesmo ...
# 3  Matérias corantes orgânicas sintéticas, mesmo ...
# 4  Matérias corantes orgânicas sintéticas, mesmo ...

# %%
# Caminho do arquivo
arquivo_pais = r'\\wsl$\Ubuntu\home\edcarlos\work_environment\datalake\raw_data\PAIS.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_pais = pd.read_csv(arquivo_pais, sep=';',  encoding='latin1')  # Ou tente 'ISO-8859-1'
# Exibir as primeiras linhas do DataFrame
df_pais.head()
# Out:
#    CO_PAIS  CO_PAIS_ISON3 CO_PAIS_ISOA3                 NO_PAIS  \
# 0        0            898           ZZZ            Não Definido
# 1       13              4           AFG             Afeganistão
# 2       15            248           ALA            Aland, Ilhas
# 3       17              8           ALB                 Albânia
# 4       20            724           ESP  Alboran-Perejil, Ilhas
#
#                 NO_PAIS_ING             NO_PAIS_ESP
# 0               Not defined             No definido
# 1               Afghanistan              Afganistan
# 2             Aland Islands            Alans, Islas
# 3                   Albania                 Albania
# 4  Alboran-Perejil, Islands  Alboran-Perejil, Islas

# %%
# Garantir que cd_urf e CO_URF sejam do mesmo tipo
df1 = df['cd_pais'] = df['cd_pais'].astype(str)
df_pais['CO_PAIS'] = df_pais['CO_PAIS'].astype(str)

# Fazer o merge para substituir os códigos pelos nomes das URFs
df1 = df.merge(df_pais, left_on='cd_pais', right_on='CO_PAIS', how='left')

# Exibir as primeiras linhas para verificar se deu certo
df1.head()
# Out:
#   cd_pais sg_ufmun   cd_mun  kg_liquido  vl_dolarfob data_importacao_mun  \
# 0     361       rs  4311809        7000        26243          2024-12-01
# 1     361       rs  4311809        7000        26243          2024-12-01
# 2     361       rs  4311809        7000        26243          2024-12-01
# 3     361       rs  4311809        7000        26243          2024-12-01
# 4     361       rs  4311809        7000        26243          2024-12-01
#
#                                           NO_SH4_POR CO_PAIS  CO_PAIS_ISON3  \
# 0  Matérias corantes orgânicas sintéticas, mesmo ...     361            356
# 1  Matérias corantes orgânicas sintéticas, mesmo ...     361            356
# 2  Matérias corantes orgânicas sintéticas, mesmo ...     361            356
# 3  Matérias corantes orgânicas sintéticas, mesmo ...     361            356
# 4  Matérias corantes orgânicas sintéticas, mesmo ...     361            356
#
#   CO_PAIS_ISOA3 NO_PAIS NO_PAIS_ING NO_PAIS_ESP
# 0           IND   Índia       India       India
# 1           IND   Índia       India       India
# 2           IND   Índia       India       India
# 3           IND   Índia       India       India
# 4           IND   Índia       India       India

# %%
print(df1.columns)
# Out:
# Index(['cd_pais', 'sg_ufmun', 'cd_mun', 'kg_liquido', 'vl_dolarfob',
#        'data_importacao_mun', 'NO_SH4_POR', 'CO_PAIS', 'CO_PAIS_ISON3',
#        'CO_PAIS_ISOA3', 'NO_PAIS', 'NO_PAIS_ING', 'NO_PAIS_ESP'],
#       dtype='object')

# %%
df1 = df1.drop(['cd_pais', 'CO_PAIS', 'CO_PAIS_ISON3',
       'CO_PAIS_ISOA3', 'NO_PAIS_ING', 'NO_PAIS_ESP'], axis=1)
df1.head()
# Out:
#   sg_ufmun   cd_mun  kg_liquido  vl_dolarfob data_importacao_mun  \
# 0       rs  4311809        7000        26243          2024-12-01
# 1       rs  4311809        7000        26243          2024-12-01
# 2       rs  4311809        7000        26243          2024-12-01
# 3       rs  4311809        7000        26243          2024-12-01
# 4       rs  4311809        7000        26243          2024-12-01
#
#                                           NO_SH4_POR NO_PAIS
# 0  Matérias corantes orgânicas sintéticas, mesmo ...   Índia
# 1  Matérias corantes orgânicas sintéticas, mesmo ...   Índia
# 2  Matérias corantes orgânicas sintéticas, mesmo ...   Índia
# 3  Matérias corantes orgânicas sintéticas, mesmo ...   Índia
# 4  Matérias corantes orgânicas sintéticas, mesmo ...   Índia

# %%
# Caminho do arquivo
arquivo_uf_mun = r'\\wsl$\Ubuntu\home\edcarlos\work_environment\datalake\raw_data\UF_MUN.csv' #foi nomeado dessa forma porque não encontrou o arquivo porque está no wsl2
# Lendo o CSV para um DataFrame
df_uf_mun = pd.read_csv(arquivo_uf_mun, sep=';',  encoding='latin1')  # Ou tente 'ISO-8859-1'
# Exibir as primeiras linhas do DataFrame
df_uf_mun.head()
# Out:
#    CO_MUN_GEO                  NO_MUN              NO_MUN_MIN SG_UF
# 0     2502003  BELEM DO BREJO DO CRUZ  Belém do Brejo do Cruz    PB
# 1     2502052      BERNARDINO BATISTA      Bernardino Batista    PB
# 2     2502102             BOA VENTURA             Boa Ventura    PB
# 3     2502151               BOA VISTA               Boa Vista    PB
# 4     2502201               BOM JESUS               Bom Jesus    PB

# %%
# Garantir que cd_urf e CO_URF sejam do mesmo tipo
df2 = df1['cd_mun'] = df['cd_mun'].astype(str)
df_uf_mun['CO_MUN_GEO'] = df_uf_mun['CO_MUN_GEO'].astype(str)

# Fazer o merge para substituir os códigos pelos nomes das URFs
df2 = df1.merge(df_uf_mun, left_on='cd_mun', right_on='CO_MUN_GEO', how='left')

# Exibir as primeiras linhas para verificar se deu certo
df2.head()
# Out:
#   sg_ufmun   cd_mun  kg_liquido  vl_dolarfob data_importacao_mun  \
# 0       rs  4311809        7000        26243          2024-12-01
# 1       rs  4311809        7000        26243          2024-12-01
# 2       rs  4311809        7000        26243          2024-12-01
# 3       rs  4311809        7000        26243          2024-12-01
# 4       rs  4311809        7000        26243          2024-12-01
#
#                                           NO_SH4_POR NO_PAIS CO_MUN_GEO  \
# 0  Matérias corantes orgânicas sintéticas, mesmo ...   Índia    4311809
# 1  Matérias corantes orgânicas sintéticas, mesmo ...   Índia    4311809
# 2  Matérias corantes orgânicas sintéticas, mesmo ...   Índia    4311809
# 3  Matérias corantes orgânicas sintéticas, mesmo ...   Índia    4311809
# 4  Matérias corantes orgânicas sintéticas, mesmo ...   Índia    4311809
#
#   NO_MUN NO_MUN_MIN SG_UF
# 0  MARAU      Marau    RS
# 1  MARAU      Marau    RS
# 2  MARAU      Marau    RS
# 3  MARAU      Marau    RS
# 4  MARAU      Marau    RS

# %%
print(df2.columns)
# Out:
# Index(['sg_ufmun', 'cd_mun', 'kg_liquido', 'vl_dolarfob',
#        'data_importacao_mun', 'NO_SH4_POR', 'NO_PAIS', 'CO_MUN_GEO', 'NO_MUN',
#        'NO_MUN_MIN', 'SG_UF'],
#       dtype='object')

# %%
df2 = df2.drop(['cd_mun', 'CO_MUN_GEO', 'NO_MUN', 'SG_UF'], axis=1)
df2.head()
# Out:
#   sg_ufmun  kg_liquido  vl_dolarfob data_importacao_mun  \
# 0       rs        7000        26243          2024-12-01
# 1       rs        7000        26243          2024-12-01
# 2       rs        7000        26243          2024-12-01
# 3       rs        7000        26243          2024-12-01
# 4       rs        7000        26243          2024-12-01
#
#                                           NO_SH4_POR NO_PAIS NO_MUN_MIN
# 0  Matérias corantes orgânicas sintéticas, mesmo ...   Índia      Marau
# 1  Matérias corantes orgânicas sintéticas, mesmo ...   Índia      Marau
# 2  Matérias corantes orgânicas sintéticas, mesmo ...   Índia      Marau
# 3  Matérias corantes orgânicas sintéticas, mesmo ...   Índia      Marau
# 4  Matérias corantes orgânicas sintéticas, mesmo ...   Índia      Marau

# %%
df3 = df2.rename(columns={  
    'sg_ufmun': 'sg_ufmun',
    'kg_liquido': 'kg_liquido',
    'vl_dolarfob': 'vl_dolarfob',
    'data_importacao_mun': 'data_importacao_mun',
    'NO_SH4_POR': 'cd_sh4',
    'NO_PAIS': 'cd_pais',
    'NO_MUN_MIN': 'cd_mun'
    })
df2.columns = df2.columns.str.strip().str.lower().str.replace(' ', '_')
df3.head()
# Out:
#   sg_ufmun  kg_liquido  vl_dolarfob data_importacao_mun  \
# 0       rs        7000        26243          2024-12-01
# 1       rs        7000        26243          2024-12-01
# 2       rs        7000        26243          2024-12-01
# 3       rs        7000        26243          2024-12-01
# 4       rs        7000        26243          2024-12-01
#
#                                               cd_sh4 cd_pais cd_mun
# 0  Matérias corantes orgânicas sintéticas, mesmo ...   Índia  Marau
# 1  Matérias corantes orgânicas sintéticas, mesmo ...   Índia  Marau
# 2  Matérias corantes orgânicas sintéticas, mesmo ...   Índia  Marau
# 3  Matérias corantes orgânicas sintéticas, mesmo ...   Índia  Marau
# 4  Matérias corantes orgânicas sintéticas, mesmo ...   Índia  Marau

# %%
cols = ['cd_sh4', 'cd_pais', 'cd_mun']  # Lista das colunas
df3[cols] = df3[cols].apply(lambda x: x.str.strip().str.lower())
df3.head()
# Out:
#   sg_ufmun  kg_liquido  vl_dolarfob data_importacao_mun  \
# 0       rs        7000        26243          2024-12-01
# 1       rs        7000        26243          2024-12-01
# 2       rs        7000        26243          2024-12-01
# 3       rs        7000        26243          2024-12-01
# 4       rs        7000        26243          2024-12-01
#
#                                               cd_sh4 cd_pais cd_mun
# 0  matérias corantes orgânicas sintéticas, mesmo ...   índia  marau
# 1  matérias corantes orgânicas sintéticas, mesmo ...   índia  marau
# 2  matérias corantes orgânicas sintéticas, mesmo ...   índia  marau
# 3  matérias corantes orgânicas sintéticas, mesmo ...   índia  marau
# 4  matérias corantes orgânicas sintéticas, mesmo ...   índia  marau

# %%
caminho = "/home/edcarlos/work_environment/datalake/silver/importacao_mun_2024_m.csv"
df3.to_csv(caminho, index=False)
print("Arquivo salvo com sucesso!")
# Out:
# Arquivo salvo com sucesso!
